# %% [markdown]
# # Notebook to generate functions in differential_equations.py
#
# The Jacobian matrix/Newton-Raphson approach requires evaluation of the differentials of the mass balance equations to find a solution.
#
# In this notebook we use sympy to generate these differential equations, which were then copy-and-pasted into differential_equations.py.
#
# ## Python setup

# %%
# Import packages
import sympy as sp

# %% [markdown]
# Sets printing options within sympy

# %%
sp.init_printing(use_unicode=False, wrap_line=True)

# %% [markdown]
# ## Define symbols

# %%
P = sp.Symbol('P') # pressure

K1_ = sp.Symbol('K1_') # equilibrium constant
K2_ = sp.Symbol('K2_') # equilibrium constant
K3_ = sp.Symbol('K3_') # equilibrium constant
K4_ = sp.Symbol('K4_') # equilibrium constant
K5_ = sp.Symbol('K5_') # equilibrium constant
K6_ = sp.Symbol('K6_') # equilibrium constant
K7_ = sp.Symbol('K7_') # equilibrium constant
K8_ = sp.Symbol('K8_') # equilibrium constant
K9_ = sp.Symbol('K9_') # equilibrium constant
K10_ = sp.Symbol('K10_') # equilibrium constant
K11_ = sp.Symbol('K11_') # equilibrium constant
K12_ = sp.Symbol('K12_') # equilibrium constant
K13_ = sp.Symbol('K13_') # equilibrium constant
K14_ = sp.Symbol('K14_') # equilibrium constant

KD1_ = sp.Symbol('KD1_') # K&C91 appendix
KD2 = sp.Symbol('KD2') # K&C91 appendix
y = sp.Symbol('y') # K&C91 appendix

wt_S = sp.Symbol('wt_S') # wt fraction of S in the system
wt_O = sp.Symbol('wt_O') # wt fraction of O in the system that reacts
wt_Fe = sp.Symbol('wt_Fe') # wt fraction of Fe in the system
wt_C = sp.Symbol('wt_C') # wt fraction of C in the system
wt_H = sp.Symbol('wt_H') # wt fraction of H in the system
wt_X = sp.Symbol('wt_X') # wt fraction of X in the system

M_O = sp.Symbol('M_O') # molecular mass of O
M_C = sp.Symbol('M_C') # molecular mass of C
M_H = sp.Symbol('M_H') # molecular mass of H
M_S = sp.Symbol('M_S') # molecular mass of S
M_Fe = sp.Symbol('M_Fe') # molecular mass of Fe
M_O2 = sp.Symbol('M_O2') # molecular mass of O2
M_S2 = sp.Symbol('M_S2') # molecular mass of S2
M_SO2 = sp.Symbol('M_SO2') # molecular mass of SO2
M_SO3 = sp.Symbol('M_SO3') # molecular mass of SO3
M_CO = sp.Symbol('M_CO') # molecular mass of CO2
M_CO2 = sp.Symbol('M_CO2') # molecular mass of CO2
M_H2 = sp.Symbol('M_H2') # molecular mass of H2
M_H2O = sp.Symbol('M_H2O') # molecular mass of H2O
M_H2S = sp.Symbol('M_H2S') # molecular mass of H2S
M_CH4 = sp.Symbol('M_CH4') # molecular mass of CH4
M_OCS = sp.Symbol('M_OCS') # molecular mass of OCS
M_X = sp.Symbol('M_X') # molecular mass of X
M_FeO = sp.Symbol('M_FeO') # molecular mass of FeO
M_FeO15 = sp.Symbol('M_FeO15') # molecular mass of FeO1.5
M_m_ = sp.Symbol('M_m_') # molecular mass of melt anhydrous
M_m_ox = sp.Symbol('M_m_ox') # molecular mass of melt anhydrous oxide

y_S2_ = sp.Symbol('y_S2_') # fugacity coefficient of S2
y_O2_ = sp.Symbol('y_O2_') # fugacity coefficient of O2
y_SO2_ = sp.Symbol('y_SO2_') # fugacity coefficient of SO2
y_CO_ = sp.Symbol('y_CO_') # fugacity coefficient of CO
y_CO2_ = sp.Symbol('y_CO2_') # fugacity coefficient of CO2
y_H2_ = sp.Symbol('y_H2_') # fugacity coefficient of H2
y_H2O_ = sp.Symbol('y_H2O_') # fugacity coefficient of H2O
y_CH4_ = sp.Symbol('y_CH4_') # fugacity coefficient of CH4
y_H2S_ = sp.Symbol('y_H2S_') # fugacity coefficient of H2S
y_OCS_ = sp.Symbol('y_OCS_') # fugacity coefficient of OCS
y_X_ = sp.Symbol('y_X_') # fugacity coefficient of X

Fe32 = sp.Symbol('Fe32') # xFeO1.5/xFeO

a = sp.Symbol('a')
b = sp.Symbol('b')
c = sp.Symbol('c')

# %% [markdown]
# ## One volatile + O + Fe
#
# ### SOFe system

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2

# Relationship between variables
xg_SO2_ = (1.0-xg_O2_)/(1.0 + (y_SO2_/(K1_*y_S2_*y_O2_**0.5*xg_O2_**0.5*P**0.5)))
xg_S2_ = (y_SO2_*xg_SO2_)/(K1_*y_S2_*(y_O2_*xg_O2_*P)**0.5)
wm_S_ = K2_*((y_S2_*xg_S2_)/(y_O2_*xg_O2_)**0.5)
wm_SO3_ = M_SO3*((((y_S2_*xg_S2_)**0.5*(y_O2_*xg_O2_)**1.5*P**2.0)/K3_)/M_S)
Xg_t = xg_SO2_*M_SO2 + xg_S2_*M_S2 + xg_O2_*M_O2
Fe32 = ((KD1_*(y_O2_*xg_O2_*P)**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y)))

# Gas fraction from mass balance of S and O
wt_g_S = ((wt_S/M_S) - (wm_S_/M_S) - (wm_SO3_/M_SO3))/(((xg_SO2_+2.0*xg_S2_)/Xg_t) - (wm_S_/M_S) - (wm_SO3_/M_SO3))
wt_g_O = ((wt_O/M_O) - (3.0*wm_SO3_/M_SO3) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)))/(((2.0*xg_SO2_ + 2.0*xg_O2_)/Xg_t) - (3.0*wm_SO3_/M_SO3))

# SOFe_O2: Differential of wtg_S - wtg_O with respect to xg_O2 for the S-O-Fe system.
diff1 = sp.diff((wt_g_S - wt_g_O), xg_O2_)
print(diff1)

# %% [markdown]
# ### COFe system

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2

# Relationship between variables
xg_CO2_ = (1.0-xg_O2_)/(1.0 + (y_CO2_/(K1_*y_CO_*y_O2_**0.5*xg_O2_**0.5*P**0.5)))
xg_CO_ = (y_CO2_*xg_CO2_)/(K1_*y_CO_*(y_O2_*xg_O2_*P)**0.5)
xm_CO2_ = K2_*y_CO2_*xg_CO2_*P
Xm_t = xm_CO2_*M_CO2 + (1.0-xm_CO2_)*M_m_
Xg_t = xg_CO2_*M_CO2 + xg_CO_*M_CO + xg_O2_*M_O2
F = ((KD1_*(y_O2_*xg_O2_*P)**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y)))
wm_CO_ = K3_*y_CO_*xg_CO_*P

# Gas fraction from mass balance of C and O
wt_g_C = ((wt_C/M_C) - (xm_CO2_/Xm_t) - (wm_CO_/M_CO))/(((xg_CO2_+xg_CO_)/Xg_t) - (xm_CO2_/Xm_t) - (wm_CO_/M_CO))
wt_g_O = ((wt_O/M_O) - (2.0*xm_CO2_/Xm_t) - (wm_CO_/M_CO) - (wt_Fe/M_Fe)*((1.5*F+1.0)/(F+1.0)))/(((2.0*xg_CO2_ + xg_CO_ + 2.0*xg_O2_)/Xg_t)-(2.0*xm_CO2_/Xm_t) - (wm_CO_/M_CO))

# COFe_O2: Differential of wtg_C - wtg_O with respect to xg_O2 for the C-O-Fe system.
diff1 = sp.diff((wt_g_C - wt_g_O), xg_O2_)
print(diff1)

# %% [markdown]
# ### HOFe system with and without dissolved H2 in the melt

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2

# Relationship between variables
xg_H2O_ = (1.0-xg_O2_)/(1.0 + (y_H2O_/(K1_*y_H2_*y_O2_**0.5*xg_O2_**0.5*P**0.5)))
xg_H2_ = (y_H2O_*xg_H2O_)/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)
xm_H2O_ = (K2_*y_H2O_*xg_H2O_*P)**0.5
Xm_t = xm_H2O_*M_H2O + (1.0-xm_H2O_)*M_m_
Xg_t = xg_H2O_*M_H2O + xg_H2_*M_H2 + xg_O2_*M_O2
Fe32 = ((KD1_*(y_O2_*xg_O2_*P)**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y)))
wm_H2_ = K3_*y_H2_*xg_H2_*P

# Gas fraction from mass balance of H and O
wt_g_O = ((wt_O/M_O) - (xm_H2O_/Xm_t) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)))/(((xg_H2O_ + 2.0*xg_O2_)/Xg_t)-(xm_H2O_/Xm_t))
# Uncomment one of the lines below
#wt_g_H = ((wt_H/(2.0*M_H)) - (xm_H2O_/Xm_t))/(((xg_H2O_+xg_H2_)/Xg_t) - (xm_H2O_/Xm_t)) # no dissolved H2
wt_g_H = ((wt_H/(2.0*M_H)) - (xm_H2O_/Xm_t) - (wm_H2_/M_H2))/(((xg_H2O_+xg_H2_)/Xg_t) - (xm_H2O_/Xm_t) - (wm_H2_/M_H2)) # dissolved H2

# HOFe_O2: Differential of wtg_H - wtg_O with respect to xg_O2 for the H-O-Fe system with no dissolved H2 in the melt [if no dissolved H2 used]
# HOFe_O2_2: Differential of wtg_H - wtg_O with respect to xg_O2 for the H-O-Fe system [if dissolved H2 used]
diff1 = sp.diff((wt_g_H - wt_g_O), xg_O2_)
print(diff1)

# %% [markdown]
# ### SOFe - melt only
#
# Within function eq_SOFe_melt in equilibrium_equations.py

# %%
fO2 = sp.Symbol('fO2') # fO2

Fe32_ = ((KD1_*fO2**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*(fO2**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*(fO2**(0.5*y)))
Fe3T = Fe32_/(1+Fe32_)
S62 = (K3_/K2_)*fO2**2.
S6T = S62/(1+S62)
mb = wt_O - ((wt_H/M_H)/2.)*M_O - ((wt_C/M_C)*2.*M_O) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)) - (((S6T*wt_S)/M_S)*3.*M_O)

diff = sp.diff(mb, fO2)
print(diff)

# %% [markdown]
# ## Two volatiles + O + Fe
#
# ### COHFe system with and without dissolved H2, CO, or CH4

# %% [markdown]
# Solving for O2 and CO

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_CO_ = sp.Symbol('xg_CO_') # gas mole fration of CO

# Relationship between variables
xg_CO2_ = (K2_*y_CO_*xg_CO_*(y_O2_*xg_O2_*P)**0.5)/y_CO2_
a = (y_CO2_*xg_CO2_*y_H2O_**2.0)/(K3_*y_CH4_*(y_O2_*xg_O2_)**2.0)
b = 1.0 + (y_H2O_/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5))
c = xg_CO2_ + xg_CO_ + xg_O2_ - 1.0
xg_H2O_ = (-b + (b**2.0-(4.0*a*c))**0.5)/(2.0*a)
xg_H2_ = (y_H2O_*xg_H2O_)/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)

# %% [markdown]
# Solving for O2 and H2

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_H2_ = sp.Symbol('xg_H2_') # gas mole fration of H2

xg_H2O_ = (xg_H2_ * (K1_ * y_H2_ * (y_O2_ * xg_O2_ * P) ** 0.5))/ y_H2O_
xg_CO2_ = (1.-xg_O2_-xg_H2_-xg_H2O_)/(1.+(y_CO2_ * (y_H2O_ * xg_H2O_) ** 2.0) / (K3_ * y_CH4_ * (y_O2_ * xg_O2_) ** 2.0) + (y_CO2_/(K2_*y_CO_*(y_O2_*xg_O2_*P)**0.5)))
xg_CO_ = (y_CO2_ * xg_CO2_) / (K2_ * y_CO_ * (y_O2_ * xg_O2_ * P) ** 0.5)

# %% [markdown]
# Solving for O2 and CO2

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_CO2_ = sp.Symbol('xg_CO2_') # gas mole fration of CO2

# Relationship between variables
xg_CO_ = (xg_CO2_*y_CO2_)/(K2_*y_CO_*(y_O2_*xg_O2_*P)**0.5)
a = (y_CO2_*xg_CO2_*y_H2O_**2.0)/(K3_*y_CH4_*(y_O2_*xg_O2_)**2.0)
b = 1.0 + (y_H2O_/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5))
c = xg_CO2_ + xg_CO_ + xg_O2_ - 1.0
xg_H2O_ = (-b + (b**2.0-(4.0*a*c))**0.5)/(2.0*a)
xg_H2_ = (y_H2O_*xg_H2O_)/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)

# %% [markdown]
# Solving for O2 and H2O

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_H2O_ = sp.Symbol('xg_H2O_') # gas mole fration of H2O

xg_H2_ = (xg_H2O_*y_H2O_)/(K1_ * y_H2_ * (y_O2_ * xg_O2_ * P) ** 0.5)
xg_CO2_ = (1.-xg_O2_-xg_H2_-xg_H2O_)/(1.+(y_CO2_ * (y_H2O_ * xg_H2O_) ** 2.0) / (K3_ * y_CH4_ * (y_O2_ * xg_O2_) ** 2.0) + (y_CO2_/(K2_*y_CO_*(y_O2_*xg_O2_*P)**0.5)))
xg_CO_ = (y_CO2_ * xg_CO2_) / (K2_ * y_CO_ * (y_O2_ * xg_O2_ * P) ** 0.5)

# %% [markdown]
# Common relationships between variables

# %%
xg_CH4_ = (y_CO2_*xg_CO2_*(y_H2O_*xg_H2O_)**2.0)/(K3_*y_CH4_*(y_O2_*xg_O2_)**2.0)
xm_H2O_ = (K4_*y_H2O_*xg_H2O_*P)**0.5
xm_CO2_ = K5_*y_CO2_*xg_CO2_*P
Xm_t = xm_CO2_*M_CO2 + xm_H2O_*M_H2O + (1.0-xm_CO2_-xm_H2O_)*M_m_
Xg_t = xg_CO2_*M_CO2 + xg_CO_*M_CO + xg_O2_*M_O2 + xg_H2O_*M_H2O + xg_H2_*M_H2 + xg_CH4_*M_CH4
Fe32 = ((KD1_*(y_O2_*xg_O2_*P)**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y)))

# Additional relationships if H2, CO, and CH4 can dissolve
wm_H2_ = K6_*y_H2_*xg_H2_*P
wm_CO_ = K7_*y_CO_*xg_CO_*P
wm_CH4_ = K8_*y_CH4_*xg_CH4_*P

# %% [markdown]
# Mass balance
#
# With no dissolved H2, CO, and CH4

# %%
# Gas fraction from mass balance of H, C, and O
wt_g_H = ((wt_H/(2.0*M_H)) - (xm_H2O_/Xm_t))/(((xg_H2O_+xg_H2_+2.0*xg_CH4_)/Xg_t) - (xm_H2O_/Xm_t))
wt_g_C = ((wt_C/M_C) - (xm_CO2_/Xm_t))/(((xg_CO2_+xg_CO_+xg_CH4_)/Xg_t) - (xm_CO2_/Xm_t))
wt_g_O = ((wt_O/M_O) - (((2.0*xm_CO2_)+xm_H2O_)/Xm_t) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)))/(((2.0*xg_CO2_ + xg_CO_ + 2.0*xg_O2_ + xg_H2O_)/Xg_t)-(((2.0*xm_CO2_) + xm_H2O_)/Xm_t))

# %% [markdown]
# With dissolved H2, CO, and CH4

# %%
# Gas fraction from mass balance of H, C, and O
wt_g_C = ((wt_C/M_C) - (xm_CO2_/Xm_t) - (wm_CO_/M_CO) - (wm_CH4_/M_CH4))/(((xg_CO2_+xg_CO_+xg_CH4_)/Xg_t) - (xm_CO2_/Xm_t) - (wm_CO_/M_CO) - (wm_CH4_/M_CH4))
wt_g_O = ((wt_O/M_O) - (xm_H2O_/Xm_t) - ((2.0*xm_CO2_)/Xm_t) - (wm_CO_/M_CO) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)))/(((2.0*xg_CO2_ + xg_CO_ + 2.0*xg_O2_ + xg_H2O_)/Xg_t) - (xm_H2O_/Xm_t) - ((2.0*xm_CO2_)/Xm_t) -(wm_CO_/M_CO))
wt_g_H = ((wt_H/(2.0*M_H)) - (xm_H2O_/Xm_t)  - (wm_H2_/M_H2) - ((2.*wm_CH4_)/M_CH4))/(((xg_H2O_+xg_H2_+2.0*xg_CH4_)/Xg_t) - (xm_H2O_/Xm_t) - (wm_H2_/M_H2) - ((2.*wm_CH4_)/M_CH4))

# %% [markdown]
# Differentials
#
# Solving for CO and O2

# %%
# CHOFe_CO_O2: Differential of wtg_C - wtg_O with respect to xg_O2 for the C-H-O-Fe system with no dissolved H2, CH4, or CO in the melt
# CHOFe_CO_O2_2: Differential of wtg_C - wtg_O with respect to xg_O2 for the C-H-O-Fe system
diff_CO_O = sp.diff((wt_g_C - wt_g_O), xg_O2_) # mass balance of C - O wrt xg_O2
print(diff_CO_O)

# %%
# CHOFe_CO_CO: Differential of wtg_C - wtg_O with respect to xg_CO for the C-H-O-Fe system with no dissolved H2, CH4, or CO in the melt
# CHOFe_CO_CO_2: Differential of wtg_C - wtg_O with respect to xg_CO for the C-H-O-Fe system
diff_CO_CO = sp.diff((wt_g_C - wt_g_O), xg_CO_) # mass balance of C - O wrt xg_CO
print(diff_CO_CO)

# %%
# CHOFe_CH_O2: Differential of wtg_C - wtg_H with respect to xg_CO for the C-H-O-Fe system with no dissolved H2, CH4, or CO in the melt
# CHOFe_CO_O2_2: Differential of wtg_C - wtg_H with respect to xg_O2 for the C-H-O-Fe system
diff_CH_O = sp.diff((wt_g_C - wt_g_H), xg_O2_) # mass balance of C - O wrt xg_O2
print(diff_CH_O)

# %%
# CHOFe_CH_CO: Differential of wtg_C - wtg_H with respect to xg_CO for the C-H-O-Fe system with no dissolved H2, CH4, or CO in the melt
# CHOFe_CO_O2_2: Differential of wtg_C - wtg_H with respect to xg_CO for the C-H-O-Fe system
diff_CH_CO = sp.diff((wt_g_C - wt_g_H), xg_CO_) # mass balance of C - O wrt xg_CO
print(diff_CH_CO)

# %% [markdown]
# Solving for O2 and H2

# %%
# CHOFe_HO_O2_2: Differential of wtg_H - wtg_O with respect to xg_O2 for the C-H-O-Fe system
diff_HO_O = sp.diff((wt_g_H - wt_g_O), xg_O2_) # mass balance of H - O wrt xg_O2
print(diff_HO_O)

# %%
# CHOFe_HO_CO_2: Differential of wtg_H - wtg_O with respect to xg_H2 for the C-H-O-Fe system
diff_HO_H = sp.diff((wt_g_H - wt_g_O), xg_H2_) # mass balance of H - O wrt xg_H2
print(diff_HO_H)

# %%
# CHOFe_CH_O2_2: Differential of wtg_H - wtg_C with respect to xg_O2 for the C-H-O-Fe system
diff_HC_O = sp.diff((wt_g_H - wt_g_C), xg_O2_) # mass balance of H - C wrt xg_O2
print(diff_HC_O)

# %%
# CHOFe_CO_O2_2: Differential of wtg_C - wtg_H with respect to xg_H2 for the C-H-O-Fe system
diff_HC_H = sp.diff((wt_g_H - wt_g_C), xg_H2_) # mass balance of H - C wrt xg_H2
print(diff_HC_H)

# %% [markdown]
# Solving for O2 and CO2

# %%
# CHOFe_CO_O2_2a: Differential of wtg_C - wtg_O with respect to xg_O2 for the C-H-O-Fe system
diff_CO_O = sp.diff((wt_g_C - wt_g_O), xg_O2_) # mass balance of C - O wrt xg_O2
print(diff_CO_O)

# %%
# CHOFe_CO_CO2_2a: Differential of wtg_C - wtg_O with respect to xg_CO2 for the C-H-O-Fe system
diff_CO_C = sp.diff((wt_g_C - wt_g_O), xg_CO2_) # mass balance of C - O wrt xg_CO2
print(diff_CO_C)

# %%
# CHOFe_CO_O2_2a: Differential of wtg_C - wtg_H with respect to xg_O2 for the C-H-O-Fe system
diff_CH_O = sp.diff((wt_g_C - wt_g_H), xg_O2_) # mass balance of C - O wrt xg_O2
print(diff_CH_O)

# %%
# CHOFe_CO_CO2_2a: Differential of wtg_C - wtg_H with respect to xg_CO2 for the C-H-O-Fe system
diff_CH_C = sp.diff((wt_g_C - wt_g_H), xg_CO2_) # mass balance of C - O wrt xg_CO2
print(diff_CH_C)

# %% [markdown]
# Solving for O2 and H2O

# %%
# CHOFe_HO_O2_2a: Differential of wtg_H - wtg_O with respect to xg_O2 for the C-H-O-Fe system
diff_HO_O = sp.diff((wt_g_H - wt_g_O), xg_O2_) # mass balance of H - O wrt xg_O2
print(diff_HO_O)
# Out:
# (-(K4_*P*xg_H2O_*y_H2O_)**0.5/(K5_*M_CO2*P*y_CO2_*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5)) + M_H2O*(K4_*P*xg_H2O_*y_H2O_)**0.5 + M_m_*(-K5_*P*y_CO2_*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5)) - (K4_*P*xg_H2O_*y_H2O_)**0.5 + 1.0)) + 0.5*wt_H/M_H - 2.0*K8_*P*y_CO2_*(xg_H2O_*y_H2O_)**2.0*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(K3_*M_CH4*(xg_O2_*y_O2_)**2.0*(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5))) - K6_*P*xg_H2O_*y_H2O_/(K1_*M_H2*(P*xg_O2_*y_O2_)**0.5))*((K4_*P*xg_H2O_*y_H2O_)**0.5*(-K5_*M_CO2*P*y_CO2_*(-1 + 0.5*xg_H2O_*y_H2O_/(K1_*xg_O2_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2
# ...

# %%
# CHOFe_HO_H2O_2a: Differential of wtg_H - wtg_O with respect to xg_H2O for the C-H-O-Fe system
diff_HO_H = sp.diff((wt_g_H - wt_g_O), xg_H2O_) # mass balance of H - O wrt xg_H2O
print(diff_HO_H)
# Out:
# (-(K4_*P*xg_H2O_*y_H2O_)**0.5/(K5_*M_CO2*P*y_CO2_*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5)) + M_H2O*(K4_*P*xg_H2O_*y_H2O_)**0.5 + M_m_*(-K5_*P*y_CO2_*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5)) - (K4_*P*xg_H2O_*y_H2O_)**0.5 + 1.0)) + 0.5*wt_H/M_H - 2.0*K8_*P*y_CO2_*(xg_H2O_*y_H2O_)**2.0*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(K3_*M_CH4*(xg_O2_*y_O2_)**2.0*(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5))) - K6_*P*xg_H2O_*y_H2O_/(K1_*M_H2*(P*xg_O2_*y_O2_)**0.5))*((K4_*P*xg_H2O_*y_H2O_)**0.5*(-K5_*M_CO2*P*y_CO2_*(-1 - y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3
# ...

# %%
# CHOFe_CH_O2_2a: Differential of wtg_H - wtg_C with respect to xg_O2 for the C-H-O-Fe system
diff_HC_O = sp.diff((wt_g_H - wt_g_C), xg_O2_) # mass balance of H - C wrt xg_O2
print(diff_HC_O)
# Out:
# (-(K4_*P*xg_H2O_*y_H2O_)**0.5/(K5_*M_CO2*P*y_CO2_*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5)) + M_H2O*(K4_*P*xg_H2O_*y_H2O_)**0.5 + M_m_*(-K5_*P*y_CO2_*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5)) - (K4_*P*xg_H2O_*y_H2O_)**0.5 + 1.0)) + 0.5*wt_H/M_H - 2.0*K8_*P*y_CO2_*(xg_H2O_*y_H2O_)**2.0*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(K3_*M_CH4*(xg_O2_*y_O2_)**2.0*(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5))) - K6_*P*xg_H2O_*y_H2O_/(K1_*M_H2*(P*xg_O2_*y_O2_)**0.5))*((K4_*P*xg_H2O_*y_H2O_)**0.5*(-K5_*M_CO2*P*y_CO2_*(-1 + 0.5*xg_H2O_*y_H2O_/(K1_*xg_O2_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2
# ...

# %%
# CHOFe_CH_H2O_2a: Differential of wtg_C - wtg_H with respect to xg_H2O for the C-H-O-Fe system
diff_HC_H = sp.diff((wt_g_H - wt_g_C), xg_H2O_) # mass balance of H - C wrt xg_H2O
print(diff_HC_H)
# Out:
# (-(K4_*P*xg_H2O_*y_H2O_)**0.5/(K5_*M_CO2*P*y_CO2_*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5)) + M_H2O*(K4_*P*xg_H2O_*y_H2O_)**0.5 + M_m_*(-K5_*P*y_CO2_*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5)) - (K4_*P*xg_H2O_*y_H2O_)**0.5 + 1.0)) + 0.5*wt_H/M_H - 2.0*K8_*P*y_CO2_*(xg_H2O_*y_H2O_)**2.0*(-xg_H2O_ - xg_O2_ + 1.0 - xg_H2O_*y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(K3_*M_CH4*(xg_O2_*y_O2_)**2.0*(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3_*y_CH4_*(xg_O2_*y_O2_)**2.0) + y_CO2_/(K2_*y_CO_*(P*xg_O2_*y_O2_)**0.5))) - K6_*P*xg_H2O_*y_H2O_/(K1_*M_H2*(P*xg_O2_*y_O2_)**0.5))*((K4_*P*xg_H2O_*y_H2O_)**0.5*(-K5_*M_CO2*P*y_CO2_*(-1 - y_H2O_/(K1_*y_H2_*(P*xg_O2_*y_O2_)**0.5))/(1.0 + y_CO2_*(xg_H2O_*y_H2O_)**2.0/(K3
# ...

# %% [markdown]
# ### CHOFe system - just melt speciation
#
# In function eq_CH_melt in equilibrium_equations.py

# %%
xm_CO2_ = sp.Symbol('xm_CO2_') # melt mole fraction of CO3
xm_H2O_ = sp.Symbol('xm_H2O_') # melt mole fraction of H2O
fO2 = sp.Symbol('fO2') # fO2

# Relationship between variables
Xm_t = xm_CO2_*M_CO2 + xm_H2O_*M_H2O + (1.0-xm_CO2_-xm_H2O_)*M_m_
wm_H2O_ = (xm_H2O_*M_H2O)/Xm_t # weight fraction
wm_CO2_ = (xm_CO2_*M_CO2)/Xm_t # weight fraction
fH2O = ((xm_H2O_)**2.)/K4_
fCO2 = xm_CO2_/K5_
fH2 = fH2O/(K1_*fO2**0.5)
wm_H2_ = (fH2*K6_)/1000000. # weight fraction
fCO = fCO2/(K2_*fO2**0.5)
wm_CO_ = (fCO*K7_)/1000000. # weight fraction
fCH4 = (fCO2*fH2O**2.)/(K3_*fO2**2.)
wm_CH4_ = (fCH4*K8_)/1000000. # weight fraction

# mass balance for C and H
wt_m_C = M_C*((wm_CO2_/M_CO2) + (wm_CO_/M_CO) + (wm_CH4_/M_CH4))
wt_m_H = M_H*(2.*(wm_H2O_/M_H2O) + 2.*(wm_H2_/M_H2) + 4.*(wm_CH4_/M_CH4))
mbC = (wt_C - wt_m_C)
mbH = (wt_H - wt_m_H)

# %%
# dmbC_C: Differential of wt_C - wtm_C with respect to xm_CO2 for the C-H-O-Fe system (melt-only)
diff = sp.diff(mbC, xm_CO2_) # mass balance of C wrt xm_CO2_
print(diff)

# %%
# dmbC_H: Differential of wt_C - wtm_C with respect to xm_H2O for the C-H-O-Fe system (melt-only)
diff = sp.diff(mbC, xm_H2O_) # mass balance of C wrt xm_H2O_
print(diff)

# %%
# dmbH_C: Differential of wt_H - wtm_H with respect to CO2 for the C-H-O-Fe system (melt-only)
diff = sp.diff(mbH, xm_CO2_) # mass balance of H wrt xm_CO2_
print(diff)

# %%
# dmbH_H: Differential of wt_H - wtm_H with respect to H2O for the C-H-O-Fe system (melt-only)
diff = sp.diff(mbH, xm_H2O_) # mass balance of H wrt xm_H2O_
print(diff)

# %% [markdown]
# ### SHOFe system
#
# #### With no dissolved H2 or H2S

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_S2_ = sp.Symbol('xg_S2_') # gas mole fration of S2

# Relationship between variables
xg_SO2_ = (K2_*y_O2_*xg_O2_*(y_S2_*xg_S2_*P)**0.5)/y_SO2_
xg_H2O_ = (1.0 - xg_O2_ - xg_S2_ - xg_SO2_)/(1.0 + ((K3_*(y_S2_*xg_S2_)**0.5*y_H2O_)/(y_H2S_*(y_O2_*xg_O2_)**0.5)) + (y_H2O_/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)))
xg_H2_ = (y_H2O_*xg_H2O_)/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)
xg_H2S_ = (K3_*(y_S2_*xg_S2_)**0.5*y_H2O_*xg_H2O_)/(y_H2S_*(y_O2_*xg_O2_)**0.5)
xm_H2O_ = (K4_*y_H2O_*xg_H2O_*P)**0.5
wm_S_ = K5_*((y_S2_*xg_S2_)/(y_O2_*xg_O2_))**0.5
wm_SO3_ = ((K6_*(y_S2_*xg_S2_)**0.5*(y_O2_*xg_O2_)**1.5*P**2.0)/M_S)*M_SO3
Xm_t = xm_H2O_*M_H2O + (1.0-xm_H2O_)*M_m_
Xg_t = xg_SO2_*M_SO2 + xg_S2_*M_S2 + xg_O2_*M_O2 + xg_H2O_*M_H2O + xg_H2_*M_H2 + xg_H2S_*M_H2S
Fe32 = ((KD1_*(y_O2_*xg_O2_*P)**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y)))

# Gas fraction from mass balance of H, S, and O
wt_g_S = ((wt_S/M_S) - (wm_S_/M_S) - (wm_SO3_/M_SO3))/(((xg_SO2_+2.0*xg_S2_+xg_H2S_)/Xg_t) - (wm_S_/M_S) - (wm_SO3_/M_SO3))
wt_g_O = ((wt_O/M_O) - (xm_H2O_/Xm_t) - (3.0*wm_SO3_/M_SO3) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)))/(((2.0*xg_SO2_ + 2.0*xg_O2_ + xg_H2O_)/Xg_t) - (xm_H2O_/Xm_t) - (3.0*wm_SO3_/M_SO3))
wt_g_H = ((wt_H/(2.0*M_H)) - (xm_H2O_/Xm_t))/(((xg_H2O_+xg_H2_+xg_H2S_)/Xg_t) - (xm_H2O_/Xm_t))

# %%
# SHOFe_SO_O2: Differential of wtg_S - wtg_O with respect to xg_O2 for the S-H-O-Fe system with no dissolved H2 or H2S
diff = sp.diff((wt_g_S - wt_g_O), xg_O2_) # mass balance of S - O wrt xg_O2
print(diff)

# %%
# SHOFe_SO_S2: Differential of wtg_S - wtg_O with respect to xg_S2 for the S-H-O-Fe system with no dissolved H2 or H2S
diff = sp.diff((wt_g_S - wt_g_O), xg_S2_) # mass balance of S - O wrt xg_S2
print(diff)

# %%
# SHOFe_SO_S2: Differential of wtg_S - wtg_H with respect to xg_O2 for the S-H-O-Fe system with no dissolved H2 or H2S
diff = sp.diff((wt_g_S - wt_g_H), xg_O2_) # mass balance of S - H wrt xg_O2
print(diff)

# %%
# SHOFe_SO_S2: Differential of wtg_S - wtg_H with respect to xg_S2 for the S-H-O-Fe system with no dissolved H2 or H2S
diff = sp.diff((wt_g_S - wt_g_H), xg_S2_) # mass balance of S - H wrt xg_S2
print(diff)

# %% [markdown]
# #### With dissolved H2S

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_S2_ = sp.Symbol('xg_S2_') # gas mole fration of S2

## relationship between variables
xg_SO2_ = (K6_*y_O2_*xg_O2_*(y_S2_*xg_S2_*P)**0.5)/y_SO2_
xg_H2O_ = (1.0 - xg_O2_ - xg_S2_ - xg_SO2_)/(1.0 + ((K7_*(y_S2_*xg_S2_)**0.5*y_H2O_)/(y_H2S_*(y_O2_*xg_O2_)**0.5)) + (y_H2O_/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)))
xg_H2_ = (y_H2O_*xg_H2O_)/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)
xg_H2S_ = (K7_*(y_S2_*xg_S2_)**0.5*y_H2O_*xg_H2O_)/(y_H2S_*(y_O2_*xg_O2_)**0.5)
Xg_t = xg_SO2_*M_SO2 + xg_S2_*M_S2 + xg_O2_*M_O2 + xg_H2O_*M_H2O + xg_H2_*M_H2 + xg_H2S_*M_H2S
xm_H2O_ = (K4_*y_H2O_*xg_H2O_*P)**0.5
Xm_t = xm_H2O_*M_H2O + (1.0-xm_H2O_)*M_m_
wm_H2O_ = (xm_H2O_*M_H2O)/Xm_t
wm_H2_ = K13_*y_H2_*xg_H2_*P
wm_H2S_ = K14_*y_H2S_*xg_H2S_*P
wm_S_ = K8_*((y_S2_*xg_S2_)/(y_O2_*xg_O2_))**0.5
wm_SO3_ = ((K9_*(y_S2_*xg_S2_)**0.5*(y_O2_*xg_O2_)**1.5*P**2.0)/M_S)*M_SO3
wm_ST_ = wm_S_ + ((M_S*wm_SO3_)/M_SO3) + ((M_S*wm_H2S_)/M_H2S)
Fe32 = ((KD1_*(y_O2_*xg_O2_*P)**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y)))
Fe3T = Fe32/(1.0+Fe32)
S62 = (wm_SO3_/M_SO3)/(wm_S_/M_S)
S6T = S62/(1.0+S62)

# Gas fraction from mass balance of H, S, and O
wt_g_O = ((wt_O/M_O) - (wm_H2O_/M_H2O) - (3.*wm_SO3_/M_SO3) - (wt_Fe/M_Fe)*((1.5*Fe32+1.)/(Fe32+1.)))/(((2.*xg_O2_ + xg_H2O_ + 2.0*xg_SO2_)/Xg_t) - (wm_H2O_/M_H2O) - (3.0*wm_SO3_/M_SO3))
wt_g_H = ((wt_H/(2.*M_H)) - (wm_H2O_/M_H2O) - (wm_H2_/M_H2) - (wm_H2S_/M_H2S))/(((xg_H2O_+xg_H2_+xg_H2S_)/Xg_t) - (wm_H2O_/M_H2O) - (wm_H2_/M_H2) - (wm_H2S_/M_H2S))
wt_g_S = ((wt_S/M_S) - (wm_S_/M_S) - (wm_SO3_/M_SO3) - (wm_H2S_/M_H2S))/(((xg_SO2_+2.0*xg_S2_+xg_H2S_)/Xg_t) - (wm_S_/M_S) - (wm_SO3_/M_SO3) - (wm_H2S_/M_H2S))

# %%
# SHOFe2_HO_O2: Differential of wtg_H - wtg_O with respect to xg_O2 for the S-H-O-Fe system
diff = sp.diff((wt_g_H - wt_g_O), xg_O2_) # mass balance of H - O wrt xg_O2
print(diff)

# %%
# SHOFe2_HO_S2: Differential of wtg_H - wtg_O with respect to xg_S2 for the S-H-O-Fe system
diff = sp.diff((wt_g_H - wt_g_O), xg_S2_) # mass balance of H - O wrt xg_S2
print(diff)

# %%
# SHOFe2_HS_O2: Differential of wtg_H - wtg_S with respect to xg_O2 for the S-H-O-Fe system
diff = sp.diff((wt_g_H - wt_g_S), xg_O2_) # mass balance of H - S wrt xg_O2
print(diff)

# %%
# SHOFe2_HS_S2: Differential of wtg_H - wtg_S with respect to xg_S2 for the S-H-O-Fe system
diff = sp.diff((wt_g_H - wt_g_S), xg_S2_) # mass balance of H - S wrt xg_S2
print(diff)

# %% [markdown]
# ### SCOFe system

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_S2_ = sp.Symbol('xg_S2_') # gas mole fration of S2

# Relationship between variables
xg_SO2_ = (K2_*y_O2_*xg_O2_*(y_S2_*xg_S2_*P)**0.5)/y_SO2_
xg_CO2_ = (1.-xg_O2_-xg_S2_-xg_SO2_)/(1.+(y_CO2_/(K1_*y_CO_*(y_O2_*xg_O2_*P)**0.5)+((y_SO2_*xg_SO2_*y_CO2_)/(K1_**3.*K3_*y_OCS_*(y_O2_*xg_O2_)**1.5*P**0.5))))
xg_CO_ = (y_CO2_*xg_CO2_)/(y_CO_*K1_*(y_O2_*xg_O2_*P)**0.5)
xg_OCS_ = ((y_CO_*xg_CO_)**3.*y_SO2_*xg_SO2_*P)/(K3_*(y_CO2_*xg_CO2_)**2.*y_OCS_)
wm_S_ = K5_*((y_S2_*xg_S2_)/(y_O2_*xg_O2_))**0.5
wm_SO3_ = ((K6_*(y_S2_*xg_S2_)**0.5*(y_O2_*xg_O2_)**1.5*P**2.)/M_S)*M_SO3
wm_ST_ = wm_S_ + ((M_S*wm_SO3_)/M_SO3)
xm_CO2_ = K4_*y_CO2_*xg_CO2_*P
Xm_t = xm_CO2_*M_CO2 + (1.-xm_CO2_)*M_m_
Xg_t = xg_CO2_*M_CO2 + xg_CO_*M_CO + xg_O2_*M_O2 + xg_SO2_*M_SO2 + xg_S2_*M_S2 + xg_OCS_*M_OCS
Fe32 = ((KD1_*(y_O2_*xg_O2_*P)**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y)))
wm_CO_ = K7_*y_CO_*xg_CO_*P

# Gas fraction from mass balance of C, S, and O
wt_g_S = ((wt_S/M_S) - (wm_S_/M_S) - (wm_SO3_/M_SO3))/(((xg_SO2_+2.*xg_S2_+xg_OCS_)/Xg_t) - (wm_S_/M_S) - (wm_SO3_/M_SO3))
wt_g_O = ((wt_O/M_O) - 2.*(xm_CO2_/Xm_t) - (3.*wm_SO3_/M_SO3) - (wm_CO_/M_CO) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)))/(((2.*xg_SO2_ + 2.*xg_O2_ + 2.*xg_CO2_ + xg_CO_ + xg_OCS_)/Xg_t) - 2.*(xm_CO2_/Xm_t) - (3.*wm_SO3_/M_SO3) - (wm_CO_/M_CO))
wt_g_C = ((wt_C/M_C) - (xm_CO2_/Xm_t) - (wm_CO_/M_CO))/(((xg_CO2_+xg_CO_+xg_OCS_)/Xg_t) - (xm_CO2_/Xm_t) - (wm_CO_/M_CO))

# %%
# SCOFe_SO_O2: Differential of wtg_S - wtg_O with respect to xg_O2 for the S-C-O-Fe system
diff = sp.diff((wt_g_S - wt_g_O), xg_O2_) # mass balance of S- O wrt xg_O2
print(diff)

# %%
# SCOFe_SO_S2: Differential of wtg_S - wtg_O with respect to xg_S2 for the S-C-O-Fe system
diff = sp.diff((wt_g_S - wt_g_O), xg_S2_) # mass balance of S - O wrt xg_S2
print(diff)

# %%
# SCOFe_SC_O2: Differential of wtg_S - wtg_C with respect to xg_O2 for the S-C-O-Fe system
diff = sp.diff((wt_g_S - wt_g_C), xg_O2_) # mass balance of S - C wrt xg_O2
print(diff)

# %%
# SCOFe_SC_O2: Differential of wtg_S - wtg_C with respect to xg_S2 for the S-C-O-Fe system
diff = sp.diff((wt_g_S - wt_g_C), xg_S2_) # mass balance of S - C wrt xg_S2
print(diff)

# %% [markdown]
# ### H2O+CO2 only

# %%
xg_CO2_ = sp.Symbol('xg_CO2_') # gas mole fraction of CO2

xg_H2O_ = 1. - xg_CO2_
xm_H2O_ = (K4_*y_H2O_*xg_H2O_*P)**0.5
xm_CO2_ = K5_*y_CO2_*xg_CO2_*P
Xm_t = xm_CO2_*M_CO2 + xm_H2O_*M_H2O + (1.0-xm_CO2_-xm_H2O_)*M_m_
Xg_t = xg_CO2_*M_CO2 + xg_H2O_*M_H2O
wt_g_C = ((wt_C/M_C) - (xm_CO2_/Xm_t))/((xg_CO2_/Xg_t) - (xm_CO2_/Xm_t))
wt_g_H = ((wt_H/(2.0*M_H)) - (xm_H2O_/Xm_t))/((xg_H2O_/Xg_t) - (xm_H2O_/Xm_t))
mbCH = (wt_g_C - wt_g_H)
  
# CH_CO2
diff = sp.diff(mbCH, xg_CO2_)
print(diff)

# %% [markdown]
# ### HOXFe

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_H2_ = sp.Symbol('xg_H2_') # gas mole fration of H2

# Relationship between variables
xg_H2O_ = (K1_*y_H2_*xg_H2_*(y_O2_*xg_O2_*P)**0.5)/y_H2O_
xg_X_ = 1. - xg_O2_ - xg_H2_ - xg_H2O_
Xg_t = xg_H2O_*M_H2O + xg_H2_*M_H2 + xg_O2_*M_O2 + xg_X_*M_X

# the melt
xm_H2O_ = (K2_*y_H2O_*xg_H2O_*P)**0.5
Xm_t = xm_H2O_*M_H2O + (1.0-xm_H2O_)*M_m_
wm_H2O_ = (xm_H2O_*M_H2O)/Xm_t
wm_H2_ = K3_*y_H2_*xg_H2_*P
wm_X_ = K4_*y_X_*xg_X_*P
Fe32 = ((KD1_*(y_O2_*xg_O2_*P)**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y)))

# Gas fraction from mass balance of O, H, and X
wt_g_O = ((wt_O/M_O) - (wm_H2O_/M_H2O) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)))/(((+ 2.0*xg_O2_ + xg_H2O_)/Xg_t) - (wm_H2O_/M_H2O))
wt_g_H = ((wt_H/(2.0*M_H)) - (xm_H2O_/Xm_t)  - (wm_H2_/M_H2))/(((xg_H2O_+xg_H2_)/Xg_t) - (xm_H2O_/Xm_t) - (wm_H2_/M_H2))
wt_g_X = ((wt_X/M_X) - (wm_X_/M_X))/(((xg_X_)/Xg_t) - (wm_X_/M_X))

# %%
# HOXFe_XO_O2: Differential of wtg_X - wtg_O with respect to xg_O2 for the H-O-X-Fe system
diff = sp.diff((wt_g_X - wt_g_O), xg_O2_) # mass balance of X - O wrt xg_O2
print(diff)

# %%
# HOXFe_XO_H2: Differential of wtg_X - wtg_O with respect to xg_H2 for the H-O-X-Fe system
diff = sp.diff((wt_g_X - wt_g_O), xg_H2_) # mass balance of X - O wrt xg_H2
print(diff)

# %%
# HOXFe_XH_O2: Differential of wtg_X - wtg_H with respect to xg_O2 for the H-O-X-Fe system
diff = sp.diff((wt_g_X - wt_g_H), xg_O2_) # mass balance of X - H wrt xg_O2
print(diff)

# %%
# HOXFe_XH_H2: Differential of wtg_X - wtg_H with respect to xg_H2 for the H-O-X-Fe system
diff = sp.diff((wt_g_X - wt_g_H), xg_H2_) # mass balance of X - H wrt xg_H2
print(diff)

# %% [markdown]
# ### COXFe

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_CO_ = sp.Symbol('xg_CO_') # gas mole fration of CO

# Relationship between variables
xg_CO2_ = (K1_*y_CO_*xg_CO_*(y_O2_*xg_O2_*P)**0.5)/y_CO2_
xg_X_ = 1. - xg_O2_ - xg_CO_ - xg_CO2_
Xg_t = xg_CO2_*M_CO2 + xg_CO_*M_CO + xg_O2_*M_O2 + xg_X_*M_X

# the melt
wm_X_ = K4_*(xg_X_*y_X_*P)
xm_CO2_ = K2_*y_CO2_*xg_CO2_*P
wm_CO_ = K3_*y_CO_*xg_CO_*P
Xm_t = xm_CO2_*M_CO2 + (1.-xm_CO2_)*M_m_
Fe32 = ((KD1_*(y_O2_*xg_O2_*P)**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y)))

# Gas fraction from mass balance of O, C, and X
wt_g_X = ((wt_X/M_X) - (wm_X_/M_X))/(((xg_X_)/Xg_t) - (wm_X_/M_X))
wt_g_O = ((wt_O/M_O) - 2.*(xm_CO2_/Xm_t) - (wm_CO_/M_CO) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)))/(((2.*xg_O2_ + 2.*xg_CO2_ + xg_CO_)/Xg_t) - 2.*(xm_CO2_/Xm_t) - (wm_CO_/M_CO))
wt_g_C = ((wt_C/M_C) - (xm_CO2_/Xm_t) - (wm_CO_/M_CO))/(((xg_CO2_+xg_CO_)/Xg_t) - (xm_CO2_/Xm_t) - (wm_CO_/M_CO))

# %%
# COXFe_XO_O2: Differential of wtg_X - wtg_O with respect to xg_O2 for the C-O-X-Fe system
diff = sp.diff((wt_g_X - wt_g_O), xg_O2_) # mass balance of X - O wrt xg_O2
print(diff)

# %%
# COXFe_XO_CO: Differential of wtg_X - wtg_O with respect to xg_CO for the C-O-X-Fe system
diff = sp.diff((wt_g_X - wt_g_O), xg_CO_) # mass balance of X - O wrt xg_CO
print(diff)

# %%
# COXFe_XC_O2: Differential of wtg_X - wtg_C with respect to xg_O2 for the C-O-X-Fe system
diff = sp.diff((wt_g_X - wt_g_C), xg_O2_) # mass balance of X - C wrt xg_O2
print(diff)

# %%
# COXFe_XC_CO: Differential of wtg_X - wtg_C with respect to xg_CO for the C-O-X-Fe system
diff = sp.diff((wt_g_X - wt_g_C), xg_CO_) # mass balance of X - C wrt xg_CO
print(diff)

# %% [markdown]
# ## Three volatiles + O + Fe
#
# ### SCHOFe system with no dissolved H2, CO, CH4, or H2S (both square-root and linear relationship for H2O)
#
# This system can be solved using different combinations of guessed species - the differentials must be generated for each set independendently.
#
# #### Solving for O2, CO, and S2

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_CO_ = sp.Symbol('xg_CO_') # gas mole fration of CO
xg_S2_ = sp.Symbol('xg_S2_') # gas mole fration of S2

# Relationship between variables
xg_CO2_ = (K2_*y_CO_*xg_CO_*(y_O2_*xg_O2_*P)**0.5)/y_CO2_
xg_SO2_ = (K6_*y_O2_*xg_O2_*(y_S2_*xg_S2_*P)**0.5)/y_SO2_
xg_OCS_ = ((xg_CO_*y_CO_)**3.0*xg_SO2_*y_SO2_*P)/(y_OCS_*(xg_CO2_*y_CO2_)**2.0*K10_)
a = (y_CO2_*xg_CO2_*y_H2O_**2.0)/(K3_*y_CH4_*(y_O2_*xg_O2_)**2.0)
b = 1.0 + (y_H2O_/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)) + ((K7_*(y_S2_*xg_S2_)**0.5*y_H2O_)/(y_H2S_*(y_O2_*xg_O2_)**0.5))
c = xg_CO2_ + xg_CO_ + xg_O2_ + xg_S2_ + xg_SO2_ + xg_OCS_ - 1.0
xg_H2O_ = (-b + (b**2.0-(4.0*a*c))**0.5)/(2.0*a)
xg_H2_ = (y_H2O_*xg_H2O_)/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)
xg_CH4_ = (y_CO2_*xg_CO2_*(y_H2O_*xg_H2O_)**2.0)/(K3_*y_CH4_*(y_O2_*xg_O2_)**2.0)
xg_H2S_ = (K7_*(y_S2_*xg_S2_)**0.5*y_H2O_*xg_H2O_)/(y_H2S_*(y_O2_*xg_O2_)**0.5)

# %% [markdown]
# #### Solving for O2, H2, and S2

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_H2_ = sp.Symbol('xg_H2_') # gas mole fration of H2
xg_S2_ = sp.Symbol('xg_S2_') # gas mole fration of S2

# Relationship between variables
xg_H2O_ = (xg_H2_*K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)/y_H2O_
xg_H2S_ = (K7_*(y_S2_*xg_S2_)**0.5*y_H2O_*xg_H2O_)/(y_H2S_*(y_O2_*xg_O2_)**0.5)
xg_SO2_ = (K6_*y_O2_*xg_O2_*(y_S2_*xg_S2_*P)**0.5)/y_SO2_
xg_CO2_ = (1.0 - xg_S2_ - xg_O2_ - xg_H2_ - xg_H2O_ - xg_H2S_ - xg_SO2_)/(1.0 + (y_CO2_/(K2_*y_CO_*(y_O2_*xg_O2_*P)**0.5)) + ((y_CO2_*y_SO2_*xg_SO2_)/(K2_**3.0*K10_*y_OCS_*(y_O2_*xg_O2_)**1.5*P**0.5)) + ((y_CO2_*(y_H2O_*xg_H2O_)**2.0)/(K3_*y_CH4_*(y_O2_*xg_O2_)**2.0)))
xg_CO_ = (y_CO2_*xg_CO2_)/(K2_*y_CO_*(y_O2_*xg_O2_*P)**0.5)
xg_CH4_ = (y_CO2_*xg_CO2_*(y_H2O_*xg_H2O_)**2.0)/(K3_*y_CH4_*(y_O2_*xg_O2_)**2.0)
xg_OCS_ = ((xg_CO_*y_CO_)**3.0*xg_SO2_*y_SO2_*P)/(y_OCS_*(xg_CO2_*y_CO2_)**2.0*K10_)

# %% [markdown]
# #### Solving for O2, CO, and H2

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_CO_ = sp.Symbol('xg_CO_') # gas mole fration of CO
xg_H2_ = sp.Symbol('xg_H2_') # gas mole fration of H2

# Relationship between variables
xg_H2O_ = (xg_H2_*K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)/y_H2O_
xg_CO2_ = (K2_*y_CO_*xg_CO_*(y_O2_*xg_O2_*P)**0.5)/y_CO2_
xg_CH4_ = (y_CO2_*xg_CO2_*(y_H2O_*xg_H2O_)**2.0)/(K3_*y_CH4_*(y_O2_*xg_O2_)**2.0)
a = 1.0
b = ((K6_*(y_S2_*P)**0.5*y_O2_*xg_O2_)/y_SO2_) + (((K7_*y_H2O_*xg_H2O_)/y_H2S_)*(y_S2_/(y_O2_*xg_O2_))**0.5) + (((y_CO_*xg_CO_)**3.0*P**1.5*K6_*y_S2_**0.5*y_O2_*xg_O2_)/(K10_*y_OCS_*(y_CO2_*xg_CO2_)**2.0))
c = xg_O2_ + xg_CO_ + xg_CO2_ + xg_H2_ + xg_H2O_ + xg_CH4_ - 1.0
xg_S2_ = ((-b + (b**2.0-(4.0*a*c))**0.5)/(2.0*a))**2.0
xg_SO2_ = (K6_*y_O2_*xg_O2_*(y_S2_*xg_S2_*P)**0.5)/y_SO2_
xg_H2S_ = (K7_*(y_S2_*xg_S2_)**0.5*y_H2O_*xg_H2O_)/(y_H2S_*(y_O2_*xg_O2_)**0.5)
xg_OCS_ = ((xg_CO_*y_CO_)**3.0*xg_SO2_*y_SO2_*P)/(y_OCS_*(xg_CO2_*y_CO2_)**2.0*K10_)

# %% [markdown]
# Common relationships between variables in the melt

# %%
# H2O in the melt - either square-root relationship or linear
xm_H2O_ = (K4_*y_H2O_*xg_H2O_*P)**0.5 # square-root
# xm_H2O_ = K4_*y_H2O_*xg_H2O_*P # linear

xm_CO2_ = K5_*y_CO2_*xg_CO2_*P
wm_S_ = K8_*((y_S2_*xg_S2_)/(y_O2_*xg_O2_))**0.5
wm_SO3_ = ((K9_*(y_S2_*xg_S2_)**0.5*(y_O2_*xg_O2_)**1.5*P**2.0)/M_S)*M_SO3
Xm_t = xm_CO2_*M_CO2 + xm_H2O_*M_H2O + (1.0-xm_CO2_-xm_H2O_)*M_m_
Xg_t = xg_CO2_*M_CO2 + xg_CO_*M_CO + xg_O2_*M_O2 + xg_H2O_*M_H2O + xg_H2_*M_H2 + xg_CH4_*M_CH4 + xg_SO2_*M_SO2 + xg_S2_*M_S2 + xg_H2S_*M_H2S + xg_OCS_*M_OCS
Fe32 = ((KD1_*(y_O2_*xg_O2_*P)**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y)))

# Additional relationships if considering dissolved H2, CO, CH4, and H2S in the melt
wm_H2O_ = (xm_H2O_*M_H2O)/Xm_t
wm_CO2_ = (xm_CO2_*M_CO2)/Xm_t
wm_CO_ = K11_*y_CO_*xg_CO_*P
wm_CH4_ = K12_*y_CH4_*xg_CH4_*P
wm_H2_ = K13_*y_H2_*xg_H2_*P
wm_H2S_ = K14_*y_H2S_*xg_H2S_*P

# %% [markdown]
# Mass balances if H2, CO, CH4, and H2S are insoluble

# %%
# Gas fraction from mass balance of C, H, S, and O
wt_g_C = ((wt_C/M_C) - (xm_CO2_/Xm_t))/(((xg_CO2_+xg_CO_+xg_CH4_+xg_OCS_)/Xg_t) - (xm_CO2_/Xm_t))
wt_g_O = ((wt_O/M_O) - (xm_H2O_/Xm_t) - ((2.0*xm_CO2_)/Xm_t) - (3.0*wm_SO3_/M_SO3) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)))/(((2.0*xg_CO2_ + xg_CO_ + 2.0*xg_O2_ + xg_H2O_ + 2.0*xg_SO2_ + xg_OCS_)/Xg_t) - (xm_H2O_/Xm_t) - ((2.0*xm_CO2_)/Xm_t) - (3.0*wm_SO3_/M_SO3))
wt_g_H = ((wt_H/(2.0*M_H)) - (xm_H2O_/Xm_t))/(((xg_H2O_+xg_H2_+2.0*xg_CH4_+xg_H2S_)/Xg_t) - (xm_H2O_/Xm_t))
wt_g_S = ((wt_S/M_S) - (wm_S_/M_S) - (wm_SO3_/M_SO3))/(((xg_SO2_+2.0*xg_S2_+xg_H2S_+xg_OCS_)/Xg_t) - (wm_S_/M_S) - (wm_SO3_/M_SO3))

# %% [markdown]
# Mass balances if H2, CO, CH4, and H2S are soluble

# %%
# Gas fraction from mass balance of C, H, S, and O
wt_g_C = ((wt_C/M_C) - (wm_CO2_/M_CO2) - (wm_CH4_/M_CH4) - (wm_CO_/M_CO))/(((xg_CO2_+xg_CO_+xg_CH4_+xg_OCS_)/Xg_t) - (wm_CO2_/M_CO2) - (wm_CH4_/M_CH4) - (wm_CO_/M_CO))
wt_g_O = ((wt_O/M_O) - (wm_H2O_/M_H2O) - ((2.0*wm_CO2_)/M_CO2) - (3.0*wm_SO3_/M_SO3) - (wm_CO_/M_CO) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)))/(((2.0*xg_CO2_ + xg_CO_ + 2.0*xg_O2_ + xg_H2O_ + 2.0*xg_SO2_ + xg_OCS_ )/Xg_t) - (wm_H2O_/M_H2O) - ((2.0*wm_CO2_)/M_CO2) - (3.0*wm_SO3_/M_SO3) - (wm_CO_/M_CO))
wt_g_H = ((wt_H/(2.0*M_H)) - (wm_H2O_/M_H2O) - (wm_H2_/M_H2) - (2.*wm_CH4_/M_CH4) - (wm_H2S_/M_H2S))/(((xg_H2O_+xg_H2_+2.0*xg_CH4_+xg_H2S_)/Xg_t) - (wm_H2O_/M_H2O) - (wm_H2_/M_H2) - (2.*wm_CH4_/M_CH4) - (wm_H2S_/M_H2S))
wt_g_S = ((wt_S/M_S) - (wm_S_/M_S) - (wm_SO3_/M_SO3) - (wm_H2S_/M_H2S))/(((xg_SO2_+2.0*xg_S2_+xg_H2S_+xg_OCS_)/Xg_t) - (wm_S_/M_S) - (wm_SO3_/M_SO3) - (wm_H2S_/M_H2S))

# %% [markdown]
# Differentials
#
# #### Solving for O2, CO, S2

# %%
# Differential of wtg_C - wtg_O with respect to xg_O2 for the S-C-H-O-Fe system when solving for O2, CO, and S2
# SCHOFe_OCS_CO_O2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCS_CO_O2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
# SCHOFe3_OCS_CO_O2: H2O = linear relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_O), xg_O2_) # mass balance of C - O wrt xg_O2
print(diff)

# %%
# Differential of wtg_C - wtg_O with respect to xg_CO for the S-C-H-O-Fe system when solving for O2, CO, and S2
# SCHOFe_OCS_CO_CO: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCS_CO_CO: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
# SCHOFe3_OCS_CO_CO: H2O = linear relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_O), xg_CO_) # mass balance of C - O wrt xg_CO
print(diff)

# %%
# Differential of wtg_C - wtg_O with respect to xg_S2 for the S-C-H-O-Fe system when solving for O2, CO, and S2
# SCHOFe_OCS_CO_S2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCS_CO_S2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
# SCHOFe3_OCS_CO_S2: H2O = linear relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_O), xg_S2_) # mass balance of C - O wrt xg_S2
print(diff)

# %%
# Differential of wtg_C - wtg_H with respect to xg_O2 for the S-C-H-O-Fe system when solving for O2, CO, and S2
# SCHOFe_OCS_CH_O2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCS_CH_O2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
# SCHOFe3_OCS_CH_O2: H2O = linear relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_H), xg_O2_) # mass balance of C - H wrt xg_O2
print(diff)

# %%
# Differential of wtg_C - wtg_H with respect to xg_CO for the S-C-H-O-Fe system when solving for O2, CO, and S2
# SCHOFe_OCS_CH_CO: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCS_CH_CO: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
# SCHOFe3_OCS_CH_CO: H2O = linear relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_H), xg_CO_) # mass balance of C - H wrt xg_CO
print(diff)

# %%
# Differential of wtg_C - wtg_H with respect to xg_S2 for the S-C-H-O-Fe system when solving for O2, CO, and S2
# SCHOFe_OCS_CH_S2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCS_CH_S2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
# SCHOFe3_OCS_CH_S2: H2O = linear relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_H), xg_S2_) # mass balance of C - H wrt xg_S2
print(diff)

# %%
# Differential of wtg_C - wtg_S with respect to xg_O2 for the S-C-H-O-Fe system when solving for O2, CO, and S2
# SCHOFe_OCS_CS_O2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCS_CS_O2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
# SCHOFe3_OCS_CS_O2: H2O = linear relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_S), xg_O2_) # mass balance of C - S wrt xg_O2
print(diff)

# %%
# Differential of wtg_C - wtg_S with respect to xg_CO for the S-C-H-O-Fe system when solving for O2, CO, and S2
# SCHOFe_OCS_CS_CO: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCS_CS_CO: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
# SCHOFe3_OCS_CS_CO: H2O = linear relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_S), xg_CO_) # mass balance of C - S wrt xg_CO
print(diff)

# %%
# Differential of wtg_C - wtg_S with respect to xg_S2 for the S-C-H-O-Fe system when solving for O2, CO, and S2
# SCHOFe_OCS_CS_S2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCS_CS_S2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
# SCHOFe3_OCS_CS_S2: H2O = linear relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_S), xg_S2_) # mass balance of C - S wrt xg_S2
print(diff)

# %% [markdown]
# #### Solving for O2, H2, and S2

# %%
# Differential of wtg_H - wtg_O with respect to xg_O2 for the S-C-H-O-Fe system when solving for O2, H2, and S2
# SCHOFe_OHS_HO_O2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OHS_HO_O2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_H - wt_g_O), xg_O2_) # mass balance of H - O wrt xg_O2
print(diff)

# %%
# Differential of wtg_H - wtg_O with respect to xg_H2 for the S-C-H-O-Fe system when solving for O2, H2, and S2
# SCHOFe_OHS_HO_H2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OHS_HO_H2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_H - wt_g_O), xg_H2_) # mass balance of H - O wrt xg_H2
print(diff)

# %%
# Differential of wtg_H - wtg_O with respect to xg_S2 for the S-C-H-O-Fe system when solving for O2, H2, and S2
# SCHOFe_OHS_HO_S2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OHS_HO_S2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_H - wt_g_O), xg_S2_) # mass balance of H - O wrt xg_S2
print(diff)

# %%
# Differential of wtg_H - wtg_C with respect to xg_O2 for the S-C-H-O-Fe system when solving for O2, H2, and S2
# SCHOFe_OHS_HC_O2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OHS_HC_O2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_H - wt_g_C), xg_O2_) # mass balance of H - C wrt xg_O2
print(diff)

# %%
# Differential of wtg_H - wtg_C with respect to xg_H2 for the S-C-H-O-Fe system when solving for O2, H2, and S2
# SCHOFe_OHS_HC_H2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OHS_HC_H2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_H - wt_g_C), xg_H2_) # mass balance of H - C wrt xg_H2
print(diff)

# %%
# Differential of wtg_H - wtg_C with respect to xg_S2 for the S-C-H-O-Fe system when solving for O2, H2, and S2
# SCHOFe_OHS_HC_S2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OHS_HC_S2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_H - wt_g_C), xg_S2_) # mass balance of H - C wrt xg_S2
print(diff)

# %%
# Differential of wtg_H - wtg_S with respect to xg_O2 for the S-C-H-O-Fe system when solving for O2, H2, and S2
# SCHOFe_OHS_HS_O2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OHS_HS_O2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_H - wt_g_S), xg_O2_) # mass balance of H - S wrt xg_O2
print(diff)

# %%
# Differential of wtg_H - wtg_S with respect to xg_H2 for the S-C-H-O-Fe system when solving for O2, H2, and S2
# SCHOFe_OHS_HS_H2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OHS_HS_H2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_H - wt_g_S), xg_H2_) # mass balance of H - S wrt xg_H2
print(diff)

# %%
# Differential of wtg_H - wtg_S with respect to xg_S2 for the S-C-H-O-Fe system when solving for O2, H2, and S2
# SCHOFe_OHS_HS_S2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OHS_HS_S2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_H - wt_g_S), xg_S2_) # mass balance of H - S wrt xg_S2
print(diff)

# %% [markdown]
# #### Solving for O2, CO, and H2

# %%
# Differential of wtg_C - wtg_O with respect to xg_O2 for the S-C-H-O-Fe system when solving for O2, CO, and H2
# SCHOFe_OCH_CO_O2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCH_CO_O2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_O), xg_O2_) # mass balance of C - O wrt xg_O2
print(diff)

# %%
# Differential of wtg_C - wtg_O with respect to xg_CO for the S-C-H-O-Fe system when solving for O2, CO, and H2
# SCHOFe_OCH_CO_CO: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCH_CO_CO: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_O), xg_CO_) # mass balance of C - O wrt xg_CO
print(diff)

# %%
# Differential of wtg_C - wtg_O with respect to xg_H2 for the S-C-H-O-Fe system when solving for O2, CO, and H2
# SCHOFe_OCH_CO_H2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCH_CO_H2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S
diff = sp.diff((wt_g_C - wt_g_O), xg_H2_) # mass balance of C - O wrt xg_H2
print(diff)

# %%
# Differential of wtg_C - wtg_H with respect to xg_O2 for the S-C-H-O-Fe system when solving for O2, CO, and H2
# SCHOFe_OCH_CH_O2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCH_CH_O2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S 
diff = sp.diff((wt_g_C - wt_g_H), xg_O2_) # mass balance of C - H wrt xg_O2
print(diff)

# %%
# Differential of wtg_C - wtg_H with respect to xg_CO for the S-C-H-O-Fe system when solving for O2, CO, and H2
# SCHOFe_OCH_CH_CO: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCH_CH_CO: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S 
diff = sp.diff((wt_g_C - wt_g_H), xg_CO_) # mass balance of C - H wrt xg_CO
print(diff)

# %%
# Differential of wtg_C - wtg_H with respect to xg_H2 for the S-C-H-O-Fe system when solving for O2, CO, and H2
# SCHOFe_OCH_CH_H2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCH_CH_H2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S 
diff = sp.diff((wt_g_C - wt_g_H), xg_H2_) # mass balance of C - H wrt xg_H2
print(diff)

# %%
# Differential of wtg_C - wtg_H with respect to xg_O2 for the S-C-H-O-Fe system when solving for O2, CO, and H2
# SCHOFe_OCH_CS_O2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCH_CS_O2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S 
diff = sp.diff((wt_g_C - wt_g_S), xg_O2_) # mass balance of C - S wrt xg_O2
print(diff)

# %%
# Differential of wtg_C - wtg_H with respect to xg_CO for the S-C-H-O-Fe system when solving for O2, CO, and H2
# SCHOFe_OCH_CS_CO: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCH_CS_CO: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S 
diff = sp.diff((wt_g_C - wt_g_S), xg_CO_) # mass balance of C - S wrt xg_CO
print(diff)

# %%
# Differential of wtg_C - wtg_H with respect to xg_H2 for the S-C-H-O-Fe system when solving for O2, CO, and H2
# SCHOFe_OCH_CS_H2: H2O = square-root relationship and no dissolved H2, CO, CH4 or H2S
# SCHOFe2_OCH_CS_H2: H2O = square-root relationship and dissolved H2, CO, CH4 or H2S 
diff = sp.diff((wt_g_C - wt_g_S), xg_H2_) # mass balance of C - S wrt xg_H2
print(diff)

# %% [markdown]
# ### CHOXFe
#
# #### Solving for O2, CO, and X

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_CO_ = sp.Symbol('xg_CO_') # gas mole fration of CO
xg_X_ = sp.Symbol('xg_X_') # gas mole fration of X
xg_CO2_ = (K2_*y_CO_*xg_CO_*(y_O2_*xg_O2_*P)**0.5)/y_CO2_
a = (y_CO2_*xg_CO2_*y_H2O_**2.)/(K3_*y_CH4_*(y_O2_*xg_O2_)**2.)
b = 1. + (y_H2O_/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5))
c = xg_CO2_ + xg_CO_ + xg_O2_ + xg_X_ - 1.
xg_H2O_ = (-b + (b**2.0-(4.0*a*c))**0.5)/(2.0*a)
xg_H2_ = (y_H2O_*xg_H2O_)/(K1_*y_H2_*(y_O2_*xg_O2_*P)**0.5)
xg_CH4_ = (y_CO2_*xg_CO2_*(y_H2O_*xg_H2O_)**2.0)/(K3_*y_CH4_*(y_O2_*xg_O2_)**2.0)

# %% [markdown]
# #### Solving for O2, H2, and X

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_H2_ = sp.Symbol('xg_H2_') # gas mole fration of H2
xg_X_ = sp.Symbol('xg_X_') # gas mole fration of X
xg_H2O_ = (xg_H2_ * K1_ * y_H2_ * (y_O2_ * xg_O2_ * P) ** 0.5) / y_H2O_
xg_CO2_ = (1.0 - -xg_O2_ - xg_X_ - xg_H2_ - xg_H2O_) / (1.0 + (y_CO2_ / (K2_ * y_CO_ * (y_O2_ * xg_O2_ * P) ** 0.5)) + ((y_CO2_ * (y_H2O_ * xg_H2O_) ** 2.0)/ (K3_ * y_CH4_ * (y_O2_ * xg_O2_) ** 2.0)))
xg_CO_ = (y_CO2_ * xg_CO2_) / (K2_ * y_CO_ * (y_O2_ * xg_O2_ * P) ** 0.5)
xg_CH4_ = (y_CO2_ * xg_CO2_ * (y_H2O_ * xg_H2O_) ** 2.0) / (K3_ * y_CH4_ * (y_O2_ * xg_O2_) ** 2.0)

# %% [markdown]
# #### Solving for O2, CO, and H2

# %%
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_CO_ = sp.Symbol('xg_CO_') # gas mole fration of CO
xg_H2_ = sp.Symbol('xg_H2_') # gas mole fration of H2
xg_H2O_ = (xg_H2_ * K1_ * y_H2_ * (y_O2_ * xg_O2_ * P) ** 0.5) / y_H2O_
xg_CO2_ = (K2_ * y_CO_ * xg_CO_ * (y_O2_ * xg_O2_ * P) ** 0.5) / y_CO2_
xg_CH4_ = (y_CO2_ * xg_CO2_ * (y_H2O_ * xg_H2O_) ** 2.0) / (K3_ * y_CH4_ * (y_O2_ * xg_O2_) ** 2.0)
xg_X_ = 1.0 - xg_O2_ - xg_CO_ - xg_H2_ - xg_H2O_ - xg_CO2_ - xg_CH4_

# %% [markdown]
# Common relationships between variables in the melt

# %%
Xg_t = xg_CO2_*M_CO2 + xg_CO_*M_CO + xg_O2_*M_O2 + xg_H2O_*M_H2O + xg_H2_*M_H2 + xg_CH4_*M_CH4 + xg_X_*M_X

# the melt
xm_H2O_ = (K4_*y_H2O_*xg_H2O_*P)**0.5
xm_CO2_ = K5_*y_CO2_*xg_CO2_*P
Xm_t = xm_CO2_*M_CO2 + xm_H2O_*M_H2O + (1.0-xm_CO2_-xm_H2O_)*M_m_
wm_H2O_ = (xm_H2O_*M_H2O)/Xm_t
wm_CO2_ = (xm_CO2_*M_CO2)/Xm_t
wm_CO_ = K11_*y_CO_*xg_CO_*P
wm_CH4_ = K12_*y_CH4_*xg_CH4_*P
wm_H2_ = K13_*y_H2_*xg_H2_*P
wm_X_ = K6_*y_X_*xg_X_*P
Fe32 = ((KD1_*(y_O2_*xg_O2_*P)**0.25)+(2.0*y*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y))))/(1.0 + (1.0 - 2.0*y)*KD2*(KD1_**(2.0*y))*((y_O2_*xg_O2_*P)**(0.5*y)))

# Gas fraction from mass balance of C, H, X, and O
wt_g_C = ((wt_C/M_C) - (wm_CO2_/M_CO2) - (wm_CH4_/M_CH4) - (wm_CO_/M_CO))/(((xg_CO2_+xg_CO_+xg_CH4_)/Xg_t) - (wm_CO2_/M_CO2) - (wm_CH4_/M_CH4) - (wm_CO_/M_CO))
wt_g_O = ((wt_O/M_O) - (wm_H2O_/M_H2O) - ((2.0*wm_CO2_)/M_CO2) - (wm_CO_/M_CO) - (wt_Fe/M_Fe)*((1.5*Fe32+1.0)/(Fe32+1.0)))/(((2.0*xg_CO2_ + xg_CO_ + 2.0*xg_O2_ + xg_H2O_)/Xg_t) - (wm_H2O_/M_H2O) - ((2.0*wm_CO2_)/M_CO2) - (wm_CO_/M_CO))
wt_g_H = ((wt_H/(2.0*M_H)) - (wm_H2O_/M_H2O) - (wm_H2_/M_H2) - (2.*wm_CH4_/M_CH4))/(((xg_H2O_+xg_H2_+2.0*xg_CH4_)/Xg_t) - (wm_H2O_/M_H2O) - (wm_H2_/M_H2) - (2.*wm_CH4_/M_CH4))
wt_g_X = ((wt_X/M_X) - (wm_X_/M_X))/(((xg_X_)/Xg_t) - (wm_X_/M_X))

# %% [markdown]
# Differentials
#
# #### Solving for O2, CO, and X

# %%
# CHOXFe_CO_O2: Differential of wtg_C - wtg_O with respect to xg_O2 for the C-H-O-X-Fe system when solving for O2, CO, and X
diff = sp.diff((wt_g_C - wt_g_O), xg_O2_) # mass balance of C - O wrt xg_O2
print(diff)

# %%
# CHOXFe_CO_CO: Differential of wtg_C - wtg_O with respect to xg_CO for the C-H-O-X-Fe system when solving for O2, CO, and X
diff = sp.diff((wt_g_C - wt_g_O), xg_CO_) # mass balance of C - O wrt xg_CO
print(diff)

# %%
# CHOXFe_CO_X: Differential of wtg_C - wtg_O with respect to xg_X for the C-H-O-X-Fe system when solving for O2, CO, and X
diff = sp.diff((wt_g_C - wt_g_O), xg_X_) # mass balance of C - O wrt xg_X
print(diff)

# %%
# CHOXFe_CH_O2: Differential of wtg_C - wtg_H with respect to xg_O2 for the C-H-O-X-Fe system when solving for O2, CO, and X
diff = sp.diff((wt_g_C - wt_g_H), xg_O2_) # mass balance of C - H wrt xg_O2
print(diff)

# %%
# CHOXFe_CH_CO: Differential of wtg_C - wtg_H with respect to xg_CO for the C-H-O-X-Fe system when solving for O2, CO, and X
diff = sp.diff((wt_g_C - wt_g_H), xg_CO_) # mass balance of C - H wrt xg_CO
print(diff)

# %%
# CHOXFe_CH_X: Differential of wtg_C - wtg_H with respect to xg_X for the C-H-O-X-Fe system when solving for O2, CO, and X
diff = sp.diff((wt_g_C - wt_g_H), xg_X_) # mass balance of C - H wrt xg_X
print(diff)

# %%
# CHOXFe_CX_O2: Differential of wtg_C - wtg_H with respect to xg_O2 for the C-H-O-X-Fe system when solving for O2, CO, and X
diff = sp.diff((wt_g_C - wt_g_X), xg_O2_) # mass balance of C - X wrt xg_O2
print(diff)

# %%
# CHOXFe_CX_CO: Differential of wtg_C - wtg_H with respect to xg_CO for the C-H-O-X-Fe system when solving for O2, CO, and X
diff = sp.diff((wt_g_C - wt_g_X), xg_CO_) # mass balance of C - X wrt xg_CO
print(diff)

# %%
# CHOXFe_CX_X: Differential of wtg_C - wtg_H with respect to xg_X for the C-H-O-X-Fe system when solving for O2, CO, and X
diff = sp.diff((wt_g_C - wt_g_X), xg_X_) # mass balance of C - X wrt xg_X
print(diff)

# %% [markdown]
# #### Solving for O2, H2, and X

# %%
# CHOXFe_HO_O2: Differential of wtg_H - wtg_O with respect to xg_O2 for the C-H-O-X-Fe system when solving for O2, H2, and X
diff = sp.diff((wt_g_H - wt_g_O), xg_O2_) # mass balance of H - O wrt xg_O2
print(diff)

# %%
# CHOXFe_HO_H2: Differential of wtg_H - wtg_O with respect to xg_H2 for the C-H-O-X-Fe system when solving for O2, H2, and X
diff = sp.diff((wt_g_H - wt_g_O), xg_H2_) # mass balance of H - O wrt xg_H2
print(diff)

# %%
# CHOXFe_HO_X: Differential of wtg_H - wtg_O with respect to xg_X for the C-H-O-X-Fe system when solving for O2, H2, and X
diff = sp.diff((wt_g_H - wt_g_O), xg_X_) # mass balance of H - O wrt xg_X
print(diff)

# %%
# CHOXFe_HC_O2: Differential of wtg_H - wtg_C with respect to xg_O2 for the C-H-O-X-Fe system when solving for O2, H2, and X
diff = sp.diff((wt_g_H - wt_g_C), xg_O2_) # mass balance of H - C wrt xg_O2
print(diff)

# %%
# CHOXFe_HC_H2: Differential of wtg_H - wtg_C with respect to xg_CO for the C-H-O-X-Fe system when solving for O2, H2, and X
diff = sp.diff((wt_g_H - wt_g_C), xg_H2_) # mass balance of C - H wrt xg_CO
print(diff)

# %%
# CHOXFe_HC_X: Differential of wtg_H - wtg_C with respect to xg_X for the C-H-O-X-Fe system when solving for O2, H2, and X
diff = sp.diff((wt_g_H - wt_g_C), xg_X_) # mass balance of H - C wrt xg_X
print(diff)

# %%
# CHOXFe_HX_O2: Differential of wtg_H - wtg_X with respect to xg_O2 for the C-H-O-X-Fe system when solving for O2, H2, and X
diff = sp.diff((wt_g_H - wt_g_X), xg_O2_) # mass balance of H - X wrt xg_O2
print(diff)

# %%
# CHOXFe_HX_H2: Differential of wtg_H - wtg_X with respect to xg_CO for the C-H-O-X-Fe system when solving for O2, H2, and X
diff = sp.diff((wt_g_H - wt_g_X), xg_H2_) # mass balance of H - X wrt xg_H2
print(diff)

# %%
# CHOXFe_HX_X: Differential of wtg_H - wtg_X with respect to xg_X for the C-H-O-X-Fe system when solving for O2, H2, and X
diff = sp.diff((wt_g_H - wt_g_X), xg_X_) # mass balance of H - X wrt xg_X
print(diff)

# %% [markdown]
# #### Solving for O2, CO, and H2

# %%
# CHOXFe_CO_O2: Differential of wtg_C - wtg_O with respect to xg_O2 for the C-H-O-X-Fe system when solving for O2, CO, and H2
diff = sp.diff((wt_g_C - wt_g_O), xg_O2_) # mass balance of C - O wrt xg_O2
print(diff)

# %%
# CHOXFe_CO_CO: Differential of wtg_C - wtg_O with respect to xg_CO for the C-H-O-X-Fe system when solving for O2, CO, and H2
diff = sp.diff((wt_g_C - wt_g_O), xg_CO_) # mass balance of C - O wrt xg_CO
print(diff)

# %%
# CHOXFe_CO_H2: Differential of wtg_C - wtg_O with respect to xg_H2 for the C-H-O-X-Fe system when solving for O2, CO, and H2
diff = sp.diff((wt_g_C - wt_g_O), xg_H2_) # mass balance of C - O wrt xg_H2
print(diff)

# %%
# CHOXFe_CH_O2: Differential of wtg_C - wtg_H with respect to xg_O2 for the C-H-O-X-Fe system when solving for O2, CO, and H2
diff = sp.diff((wt_g_C - wt_g_H), xg_O2_) # mass balance of C - H wrt xg_O2
print(diff)

# %%
# CHOXFe_CH_CO: Differential of wtg_C - wtg_H with respect to xg_CO for the C-H-O-X-Fe system when solving for O2, CO, and H2
diff = sp.diff((wt_g_C - wt_g_H), xg_CO_) # mass balance of C - H wrt xg_CO
print(diff)

# %%
# CHOXFe_CH_H2: Differential of wtg_C - wtg_H with respect to xg_H2 for the C-H-O-X-Fe system when solving for O2, CO, and H2
diff = sp.diff((wt_g_C - wt_g_H), xg_H2_) # mass balance of C - H wrt xg_H2
print(diff)

# %%
# CHOXFe_CX_O2: Differential of wtg_C - wtg_X with respect to xg_O2 for the C-H-O-X-Fe system when solving for O2, CO, and H2
diff = sp.diff((wt_g_C - wt_g_X), xg_O2_) # mass balance of C - X wrt xg_O2
print(diff)

# %%
# CHOXFe_CX_CO: Differential of wtg_C - wtg_X with respect to xg_CO for the C-H-O-X-Fe system when solving for O2, CO, and H2
diff = sp.diff((wt_g_C - wt_g_X), xg_CO_) # mass balance of C - X wrt xg_CO
print(diff)

# %%
# CHOXFe_CX_H2: Differential of wtg_C - wtg_X with respect to xg_H2 for the C-H-O-X-Fe system when solving for O2, CO, and H2
diff = sp.diff((wt_g_C - wt_g_X), xg_H2_) # mass balance of C - X wrt xg_H2
print(diff)

# %% [markdown]
# ### SCHOFe - melt only
#
# Linear and square-root relationship with H2O
#
# Within function eq_CHS_melt in equilibrium_equations.py

# %%
xm_CO2_ = sp.Symbol('xm_CO2_') # melt mole fraction of CO3
xm_H2O_ = sp.Symbol('xm_H2O_') # melt mole fraction of H2O
wm_S2m_ = sp.Symbol('wm_S2m_') # melt weight fraction of S

# Relationship between variables
Xm_t = xm_CO2_*M_CO2 + xm_H2O_*M_H2O + (1.0-xm_CO2_-xm_H2O_)*M_m_
wm_H2O_ = (xm_H2O_*M_H2O)/Xm_t # weight fraction
wm_CO2_ = (xm_CO2_*M_CO2)/Xm_t # weight fraction

# linear or square-root relationship
fH2O = (xm_H2O_**2.)/K2_
#fH2O = xm_H2O_/K2_

fCO2 = xm_CO2_/K11_
fH2 = fH2O/(K6_*fO2**0.5)
wm_H2_ = fH2*K7_ # weight fraction
fCO = fCO2/(K9_*fO2**0.5)
wm_CO_ = fCO*K12_ # weight fraction
fCH4 = (fCO2*fH2O**2.)/(K10_*fO2**2.)
wm_CH4_ = fCH4*K13_ # weight fraction
fS2 = (fO2*wm_S2m_**2.)/K3_**2.
fH2S = (K1_*fS2**0.5*fH2O)/fO2**0.5
wm_H2S_ = fH2S*K5_ # weight fraction
wm_S6p_ = K4_*fS2**0.5*fO2**1.5 # weight fraction

# Mass balance in the melt
wt_m_C = M_C*((wm_CO2_/M_CO2) + (wm_CO_/M_CO) + (wm_CH4_/M_CH4))
wt_m_H = M_H*(2.*(wm_H2O_/M_H2O) + 2.*(wm_H2_/M_H2) + 4.*(wm_CH4_/M_CH4) + 2.*(wm_H2S_/M_H2S))
wt_m_S = M_S*((wm_S2m_/M_S) + (wm_S6p_/M_S) + (wm_H2S_/M_H2S))
mbC = (wt_C - wt_m_C)
mbH = (wt_H - wt_m_H)
mbS = (wt_S - wt_m_S)

# %%
# Differential of mass balance of C with respect to CO2 for the S-C-H-O-Fe system in the melt
diff = sp.diff(mbC, xm_CO2_)
print(diff)

# %%
# Differential of mass balance of H with respect to CO2 for the S-C-H-O-Fe system in the melt
diff = sp.diff(mbH, xm_CO2_)
print(diff)

# %%
# Differential of mass balance of S with respect to CO2 for the S-C-H-O-Fe system in the melt
diff = sp.diff(mbS, xm_CO2_)
print(diff)

# %%
# Differential of mass balance of C with respect to H2O for the S-C-H-O-Fe system in the melt
diff = sp.diff(mbC, xm_H2O_)
print(diff)

# %%
# Differential of mass balance of H with respect to H2O for the S-C-H-O-Fe system in the melt
diff = sp.diff(mbH, xm_H2O_)
print(diff)

# %%
# Differential of mass balance of S with respect to H2O for the S-C-H-O-Fe system in the melt
diff = sp.diff(mbS, xm_H2O_)
print(diff)

# %%
# Differential of mass balance of C with respect to S2m for the S-C-H-O-Fe system in the melt
diff = sp.diff(mbC, wm_S2m_)
print(diff)

# %%
# Differential of mass balance of H with respect to S2m for the S-C-H-O-Fe system in the melt
diff = sp.diff(mbH, wm_S2m_)
print(diff)

# %%
# Differential of mass balance of C with respect to S2m for the S-C-H-O-Fe system in the melt
diff = sp.diff(mbS, wm_S2m_)
print(diff)

# %% [markdown]
# ## Isotopes
#
# ### Define variables

# %%
R_a = sp.Symbol('R_a')

T_a = sp.Symbol('T_a')
T_b = sp.Symbol('T_b')
T_c = sp.Symbol('T_c')
T_d = sp.Symbol('T_d')
T_e = sp.Symbol('T_e')
T_f = sp.Symbol('T_f')

l_a = sp.Symbol('l_a')
l_b = sp.Symbol('l_b')
l_c = sp.Symbol('l_c')
l_d = sp.Symbol('l_d')
l_e = sp.Symbol('l_e')
l_f = sp.Symbol('l_f')
l_t = sp.Symbol('l_t')

a_b = sp.Symbol('a_b')
a_c = sp.Symbol('a_c')
a_d = sp.Symbol('a_d')
a_e = sp.Symbol('a_e')
a_f = sp.Symbol('a_f')

R_a = (T_a/l_a) - 1.
l_b = T_b/(1.+a_b*R_a)
l_c = T_c/(1.+a_c*R_a)
l_d = T_d/(1.+a_d*R_a)
l_f = T_f/(1.+a_f*R_a)

# three phases
total = l_a + l_b + l_c
# five phases
total = l_a + l_b + l_c + l_d + l_e + l_f

diff = sp.diff((l_t - total), l_a) 
print(diff)

# %%
Xg_t = sp.Symbol('Xg_t') # total moles in the gas on a molecular basis
F = sp.Symbol('F') # xFeO1.5/xFeO
fO2 = sp.Symbol('fO2') # fO2
Xm_t = sp.Symbol('Xm_t') # total moles in the melt on a singular oxygen basis
Xm_t_ox = sp.Symbol('Xm_t_ox') # total moles in the melt on an oxide basis
xg_O2_ = sp.Symbol('xg_O2_') # gas mole fration of O2
xg_S2_ = sp.Symbol('xg_S2_') # gas mole fration of S2
xg_SO2_ = sp.Symbol('xg_SO2_') # gas mole fraction of SO2
xg_CO_ = sp.Symbol('xg_CO_') # gas mole fration of CO
xg_CO2_ = sp.Symbol('xg_CO2_') # gas mole fraction of CO2
xg_H2_ = sp.Symbol('xg_H2_') # gas mole fration of H2
xg_H2O_ = sp.Symbol('xg_H2O_') # gas mole fraction of H2O
xg_CH4_ = sp.Symbol('xg_CH4_') # gas mole fration of CH4
xg_H2S_ = sp.Symbol('xg_H2S_') # gas mole fration of H2S
xg_OCS_ = sp.Symbol('xg_OCS_') # gas mole fraction of OCS
xg_X_ = sp.Symbol('xg_X_') # gas mole fration of X

fH2O = sp.Symbol('fH2O') # H2O fugacity
fCO2 = sp.Symbol('fCO2') # CO2 fugacity
fH2 = sp.Symbol('fH2') # H2 fugacity
fCO = sp.Symbol('fCO') # CO fugacity
fCH4 = sp.Symbol('fCH4') # CH4 fugacity

wm_S_ = sp.Symbol('wm_S_') # melt weight fraction of S_2-
wm_S2m_ = sp.Symbol('wm_S2m_') # melt weight fraction of S
wm_SO3_ = sp.Symbol('wm_SO3_') # melt weight fraction of SO4_2-
xm_CO2_ = sp.Symbol('xm_CO2_') # melt mole fraction of CO3
wm_CO_ = sp.Symbol('wm_CO_') # melt weight fraction of CO
xm_H2O_ = sp.Symbol('xm_H2O_') # melt mole fraction of H2O
wm_H2_ = sp.Symbol('wm_H2_') # melt weight fraction of H2
wm_CH4_ = sp.Symbol('wm_CH4_') # melt weight fraction of CH4
wm_H2O_ = sp.Symbol('wm_H2O_') # melt weight fraction of H2O
wm_CO2_ = sp.Symbol('wm_CO2_') # melt weight fraction of CO3
wm_H2S_ = sp.Symbol('wm_H2S_') # melt weight fraction of H2S
