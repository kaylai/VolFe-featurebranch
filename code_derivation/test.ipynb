# %% [markdown]
# # Get values for tests
#
# This notebook runs the calculations in the tests files to get their values.
#
# ## Python set-up

# %%
import VolFe as vf
import pandas as pd

# %% [markdown]
# ## Test Pvsat functions
#
# ### Simple test of calc_pvsat function using FeOT and Fe3FeT using example 1a

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.155,
    }  # mole or weight fraction (they're the same)

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]

# %% [markdown]
# ### Simple test of calc_pvsat function using Fe2O3T and DFMQ using example 1a

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,
        "SiO2": 56.98,
        "TiO2": 1.66,
        "Al2O3": 15.52,
        "Fe2O3T": 9.47,  # Fe2O3T instead of FeOT
        "MnO": 0.24,
        "MgO": 2.96,
        "CaO": 6.49,
        "Na2O": 4.06,
        "K2O": 0.38,
        "P2O5": 0.22,
        "H2O": 1.88,
        "CO2ppm": 13.0,
        "STppm": 362.83,
        "Xppm": 0.0,
        "DFMQ": 0.0,
    }  # DFMQ instead of Fe3+/FeT

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "Fe3+/FeT"]

# %% [markdown]
# ### Simple test of calc_pvsat function using FeO and Fe2O3 using example 1a

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,
        "SiO2": 56.98,
        "TiO2": 1.66,
        "Al2O3": 15.52,
        "FeO": 8.03,  # FeO and Fe2O3 to contraint total Fe and fO2
        "Fe2O3": 2.57,  # ^
        "MnO": 0.24,
        "MgO": 2.96,
        "CaO": 6.49,
        "Na2O": 4.06,
        "K2O": 0.38,
        "P2O5": 0.22,
        "H2O": 1.88,
        "CO2ppm": 13.0,
        "STppm": 362.83,
        "Xppm": 0.0,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]

# %% [markdown]
# ### Simple test of calc_pvsat function using FeOT and DNNO using example 1a

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,
        "SiO2": 56.98,
        "TiO2": 1.66,
        "Al2O3": 15.52,
        "FeOT": 9.47,
        "MnO": 0.24,
        "MgO": 2.96,
        "CaO": 6.49,
        "Na2O": 4.06,
        "K2O": 0.38,
        "P2O5": 0.22,
        "H2O": 1.88,
        "CO2ppm": 13.0,
        "STppm": 362.83,
        "Xppm": 0.0,
        "DNNO": 1.0,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "Fe3+/FeT"]

# %% [markdown]
# ### Simple test of calc_pvsat function using FeOT and S6+/ST using example 1a

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,
        "SiO2": 56.98,
        "TiO2": 1.66,
        "Al2O3": 15.52,
        "FeOT": 9.47,
        "MnO": 0.24,
        "MgO": 2.96,
        "CaO": 6.49,
        "Na2O": 4.06,
        "K2O": 0.38,
        "P2O5": 0.22,
        "H2O": 1.88,
        "CO2ppm": 13.0,
        "STppm": 362.83,
        "Xppm": 0.0,
        "S6ST": 0.23,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]

# %% [markdown]
# ### Simple test of calc_pvsat function using FeOT, DNNO, and Fe3+/FeT

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,
        "SiO2": 56.98,
        "TiO2": 1.66,
        "Al2O3": 15.52,
        "FeOT": 9.47,
        "MnO": 0.24,
        "MgO": 2.96,
        "CaO": 6.49,
        "Na2O": 4.06,
        "K2O": 0.38,
        "P2O5": 0.22,
        "H2O": 1.88,
        "CO2ppm": 13.0,
        "STppm": 362.83,
        "Xppm": 0.0,
        "DNNO": 1.0,
        "Fe3FeT": 0.155,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], assert result1.loc[0, "Fe3+/FeT"]

# %% [markdown]
# ### Simple test of calc_pvsat function using FeOT and Fe3FeT with user defined options using example 1c

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.155,
    }  # mole or weight fraction (they're the same)

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [
        ["carbon dioxide", "Basalt_Dixon97"],
        ["hydrogen sulfide", "BasalticAndesite_Hughes24"],
        ["y_S2", "ideal"],
    ]

my_models = vf.make_df_and_add_model_defaults(my_models)

result1 = vf.calc_Pvsat(my_analysis, models=my_models)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]

# %% [markdown]
# ### Simple test of calc_pvsat function including X as Ar in basalt using example 1d

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Xppm": 20.0,  # ppm *** 20 ppm "X" added**
        "Fe3FeT": 0.155,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]

# %% [markdown]
# ### Simple test of calc_pvsat function including X as Ar in rhyolite using example 1d

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Xppm": 20.0,  # ppm *** 20 ppm "X" added**
        "Fe3FeT": 0.155,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["species X solubility", "Ar_Rhyolite_HughesIP"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result1 = vf.calc_Pvsat(my_analysis, models=my_models)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]

# %% [markdown]
# ### Simple test of calc_pvsat function including X as Ne in basalt using example 1d

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Xppm": 20.0,  # ppm *** 20 ppm "X" added**
        "Fe3FeT": 0.155,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["species X", "Ne"], ["species X solubility", "Ne_Basalt_HughesIP"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result1 = vf.calc_Pvsat(my_analysis, models=my_models)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]

# %% [markdown]
# ### Simple test of calc_pvsat function including X as Ne in rhyolite using example 1d

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Xppm": 20.0,  # ppm *** 20 ppm "X" added**
        "Fe3FeT": 0.155,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["species X", "Ne"], ["species X solubility", "Ne_Rhyolite_HughesIP"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result1 = vf.calc_Pvsat(my_analysis, models=my_models)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]

# %% [markdown]
# ## Test degassing functions
#
# ### Simple test of calc_gassing function using example 2a

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 4.17,  # wt%
        "CO2ppm": 1487.0,  # ppm
        "STppm": 1343.5,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_gassing(my_analysis)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 23
#       1 my_analysis = {
#       2         "Sample": "Sari15-04-33",
#       3         "T_C": 1200.0,  # Temperature in 'C
#    (...)
#      18         "Fe3FeT": 0.177,
#      19     }
#      21 my_analysis = pd.DataFrame(my_analysis, index=[0])
# ---> 23 result = vf.calc_gassing(my_analysis)
#      25 result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
#
# File ~\projects\VolFe\src\VolFe\batch_calculations.py:1778, in calc_gassing(setup, models, run, nr_step, nr_tol, dp_step, psat_tol, dwtg, i_nr_step, i_nr_tol, nr_step_eq)
#    1773         PT["P"] = checkingP
# ...

# %% [markdown]
# ### Simple test of calc_gassing function with sulfur saturation using example 2a

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 4.17,  # wt%
        "CO2ppm": 1487.0,  # ppm
        "STppm": 1343.5,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["sulfur_saturation", "True"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]

# %% [markdown]
# ### Simple test of calc_gassing function with closed-system degassing and initial CO2 using example 2b

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 4.17,  # wt%
        "CO2ppm": 1487.0,  # ppm
        "STppm": 1343.5,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
        "initial_CO2wtpc": 4.0,
    }  # initial CO2 content of the system in wt%

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["bulk_composition", "melt+vapor_initialCO2"], ["output csv", False]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]

# %% [markdown]
# ### Simple test of calc_gassing function with closed-system degassing and wtg using example 2b

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 4.17,  # wt%
        "CO2ppm": 1487.0,  # ppm
        "STppm": 1343.5,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
        "wt_g": 3.0,
    }  # wt% vapor in equilibrium with the melt

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["bulk_composition", "melt+vapor_wtg"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]

# %% [markdown]
# ### Simple test of calc_gassing function for open-system degassing using example 2c

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 1.0,  # wt%
        "CO2ppm": 50.0,  # ppm
        "STppm": 100,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["gassing_style", "open"], ["output csv", False]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]

# %% [markdown]
# ### Simple test of calc_gassing function for closed-system regassing using example 2d

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 4.17,  # wt%
        "CO2ppm": 1487,  # ppm
        "STppm": 1343.5,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
        "initial_CO2wtpc": 3.0,  # initial CO2 content of the system in wt%
        "final_P": 5000.0,
    }  # bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [
        ["gassing_direction", "regas"],
        ["bulk_composition", "melt+vapor_initialCO2"],
        ["output csv", False],
    ]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"],  result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]

# %% [markdown]
# ### Simple test of calc_gassing function for open-system regassing using example 2d but to 4000 bar to save time

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 4.17,  # wt%
        "CO2ppm": 1487,  # ppm
        "STppm": 1343.5,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
        "initial_CO2wtpc": 3.0,  # initial CO2 content of the system in wt%
        "final_P": 4000.0,
    }  # bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [
        ["gassing_direction", "regas"],
        ["gassing_style", "open"],
        ["output csv", False],
    ]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]

# %% [markdown]
# ### Simple test of calc_gassing function for CHOAr system in basalt using example 2e

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 2.0,  # wt%
        "CO2ppm": 500.0,  # ppm
        "STppm": 0.0,  # ppm
        "Xppm": 10.0,  # ppm <<< treating this as Ar
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_gassing(my_analysis, models=options)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgX_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgX_mf"]

# %% [markdown]
# ### Simple test of calc_gassing function for CHONe system in basalt using example 2e"

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 2.0,  # wt%
        "CO2ppm": 500.0,  # ppm
        "STppm": 0.0,  # ppm
        "Xppm": 10.0,  # ppm <<< treating this as Ar
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [
        ["species X", "Ne"],
        ["species X solubility", "Ne_Basalt_HughesIP"],
        ["output csv", False],
    ]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgX_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgX_mf"]

# %% [markdown]
# ### Simple test of calc_gassing function for CHOAr system in rhyolite using example 2e

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 2.0,  # wt%
        "CO2ppm": 500.0,  # ppm
        "STppm": 0.0,  # ppm
        "Xppm": 10.0,  # ppm <<< treating this as Ar
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [
        ["species X solubility", "Ar_Rhyolite_HughesIP"],
        ["output csv", False],
    ]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgX_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgX_mf"]

# %% [markdown]
# ### Simple test of calc_gassing function for HSO system using example 2e

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 2.0,  # wt%
        "CO2ppm": 0.0,  # ppm
        "STppm": 1000.0,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_gassing(my_analysis, models=options)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]

# %% [markdown]
# ### Simple test of calc_gassing function for CSO system using example 2e

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 0.0,  # wt%
        "CO2ppm": 500.0,  # ppm
        "STppm": 1000.0,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_gassing(my_analysis, models=options)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]

# %% [markdown]
# ## Test S2fO2 functions
#
# ### Simple test of calc_melt_S_oxybarometer function at Pvsat using example 3a

# %%
my_analysis = {
        "Sample": "Sari15-04-34",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 46.94,  # wt%
        "TiO2": 0.65,  # wt%
        "Al2O3": 16.0,  # wt%
        "FeOT": 8.92,  # wt%
        "MnO": 0.15,  # wt%
        "MgO": 7.3,  # wt%
        "CaO": 13.94,  # wt%
        "Na2O": 1.61,  # wt%
        "K2O": 0.26,  # wt%
        "P2O5": 0.07,  # wt%
        "H2O": 3.83,  # wt%
        "CO2ppm": 1109.0,  # ppm
        "STppm": 1614.12,  # ppm
        "Xppm": 0.0,
    }  # ppm

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_melt_S_oxybarometer(my_analysis)

result1.loc[0, "P (bar) sulf"], result1.loc[0, "DFMQ-sulfide"], result1.loc[0, "P (bar) anh"], result1.loc[0, "DFMQ-sulfate"]

# %% [markdown]
# ### Simple test of calc_melt_S_oxybarometer function at given P using example 3a

# %%
my_analysis = {
        "Sample": "Sari15-04-34",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 46.94,  # wt%
        "TiO2": 0.65,  # wt%
        "Al2O3": 16.0,  # wt%
        "FeOT": 8.92,  # wt%
        "MnO": 0.15,  # wt%
        "MgO": 7.3,  # wt%
        "CaO": 13.94,  # wt%
        "Na2O": 1.61,  # wt%
        "K2O": 0.26,  # wt%
        "P2O5": 0.07,  # wt%
        "H2O": 3.83,  # wt%
        "CO2ppm": 1109.0,  # ppm
        "STppm": 1614.12,  # ppm
        "Xppm": 0.0,  # ppm
        "P_bar": 1000.0,  # bar
        "Fe3FeT": 0.1,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_melt_S_oxybarometer(my_analysis)

result.loc[0, "P (bar) sulf"], result.loc[0, "DFMQ-sulfide"], result.loc[0, "P (bar) anh"], result.loc[0, "DFMQ-sulfate"]

# %% [markdown]
# ### Simple test of calc_melt_S_oxybarometer function with sulfide composition using example 3a

# %%
my_analysis = {
        "Sample": "Sari15-04-34",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 46.94,  # wt%
        "TiO2": 0.65,  # wt%
        "Al2O3": 16.0,  # wt%
        "FeOT": 8.92,  # wt%
        "MnO": 0.15,  # wt%
        "MgO": 7.3,  # wt%
        "CaO": 13.94,  # wt%
        "Na2O": 1.61,  # wt%
        "K2O": 0.26,  # wt%
        "P2O5": 0.07,  # wt%
        "H2O": 3.83,  # wt%
        "CO2ppm": 1109.0,  # ppm
        "STppm": 1614.12,  # ppm
        "Xppm": 0.0,  # ppm
        "sulf_XFe": 0.8,
        "sulf_XCu": 0.15,
        "sulf_XNi": 0.05,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_melt_S_oxybarometer(my_analysis)

result.loc[0, "P (bar) sulf"], result.loc[0, "DFMQ-sulfide"], result.loc[0, "P (bar) anh"], result.loc[0, "DFMQ-sulfate"]

# %% [markdown]
# ### Simple test of calc_melt_S_oxybarometer function with user options

# %%
my_analysis = {
        "Sample": "Sari15-04-34",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 46.94,  # wt%
        "TiO2": 0.65,  # wt%
        "Al2O3": 16.0,  # wt%
        "FeOT": 8.92,  # wt%
        "MnO": 0.15,  # wt%
        "MgO": 7.3,  # wt%
        "CaO": 13.94,  # wt%
        "Na2O": 1.61,  # wt%
        "K2O": 0.26,  # wt%
        "P2O5": 0.07,  # wt%
        "H2O": 3.83,  # wt%
        "CO2ppm": 1109.0,  # ppm
        "STppm": 1614.12,  # ppm
        "Xppm": 0.0,  # ppm
        "sulf_XFe": 0.8,
        "sulf_XCu": 0.15,
        "sulf_XNi": 0.05,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["SCSS", "Fortin15_pss"], ["SCAS", "Chowdhury19"], ["y_S2", "ideal"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_melt_S_oxybarometer(my_analysis, models=my_models)

result.loc[0, "P (bar) sulf"], result.loc[0, "DFMQ-sulfide"], result.loc[0, "P (bar) anh"], result.loc[0, "DFMQ-sulfate"]

# %% [markdown]
# ## Test other functions
#
# ### Simple test of calc_fugacity_coefficients function using example 4a

# %%
my_analysis = {
        "Sample": "test",
        "T_C": 1200.0,  # Temperature in 'C
        "P_bar": 1000.0,
    }  # Pressure in bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_fugacity_coefficients(my_analysis)

result.loc[0, "yO2"], result.loc[0, "yS2"], result.loc[0, "yCO2"]

# %% [markdown]
# ### Simple test of calc_sol_consts function using example 4b

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "P_bar": 1000.0,  # Pressure in bar
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 4.17,  # wt%
        "CO2ppm": 1487.0,  # ppm
        "STppm": 1343.5,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_sol_consts(my_analysis)

result.loc[0, "ln[C_CH4]"], result.loc[0, "ln[C_S6+]"], result.loc[0, "ln[C_H2OT]"]

# %% [markdown]
# ### Simple test of calc_pure_solubility using example 4c

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "Fe3FeT": 0.177,
        "initial_P": 5000.0,
    }  # bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_pure_solubility(my_analysis)

result.loc[1, "H2O_wtpc"], result.loc[500, "CO2_ppmw"]
# Out:
# (9.14715142977834, 2710.823512744141)

# %% [markdown]
# ### Simple test of calc_pure_solubility with user defined options using example 4c

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "Fe3FeT": 0.195,
        "initial_P": 5000.0,
    }  # bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["water", "Rhyolite_HughesIP"], ["carbon dioxide", "Rhyolite_Blank93"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_pure_solubility(my_analysis, models=my_models)

result.loc[1, "H2O_wtpc"], result.loc[500, "CO2_ppmw"]

# %% [markdown]
# ### Simple test of calc_isobar using example 4d

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "Fe3FeT": 0.177,
        "initial_P": 5000.0,
    }  # bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["COH_species", "H2O-CO2 only"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_isobar(
        my_analysis, models=my_models, initial_P=1000.0, final_P=4000.0, step_P=1000.0
    )

result.loc[80, "P_bar"], result.loc[50, "H2O_wtpc", result.loc[30, "CO2_ppm"]
